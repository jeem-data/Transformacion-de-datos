# %%
import pandas as pd
import json
import numpy as np
import os
from google.cloud import storage
from io import BytesIO
from pypdf import PdfReader  # You may need to install pypdf if you haven't already
from langchain.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate
from langchain.chains import LLMChain
#from langchain.llms import OpenAI
import vertexai
from vertexai.generative_models import GenerativeModel, Part
from langchain_google_vertexai import ChatVertexAI
from langchain.output_parsers import StructuredOutputParser, ResponseSchema
import logging

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'xenon-heading-430209-e4-7582f64a7330.json' # Rellenar con el .json correspondiente
logging.basicConfig(filename='error_log.txt', level=logging.ERROR, format='%(asctime)s %(message)s')

# %%
def leer_blob_en_memoria(bucket_name, blob_name):
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)
    pdf_content = blob.download_as_bytes()
    return pdf_content

def extraer_texto_de_pdf_bytes(pdf_bytes):
    pdf_file = BytesIO(pdf_bytes)
    reader = PdfReader(pdf_file)
    text = ''
    for page in reader.pages:
        text += page.extract_text() + '\n'
    return text

def procesar_pdf_desde_gcs_en_memoria(bucket_name, blob_name):
    pdf_bytes = leer_blob_en_memoria(bucket_name, blob_name)
    content = extraer_texto_de_pdf_bytes(pdf_bytes)
    return content

def listar_pdfs(bucket_name):
    storage_client = storage.Client()
    bucket = storage_client.get_bucket(bucket_name)
    blobs = bucket.list_blobs()

    # Filtra los archivos PDF y guarda sus URLs completas en la lista
    listado_pdfs = [f"gs://{bucket_name}/{blob.name}" for blob in blobs if blob.name.endswith('.pdf') and not blob.name.startswith('resoluciones/')]
    return listado_pdfs

def dividir_lista_pdfs(listado_pdfs):
    total = len(listado_pdfs)
    tamaño_parte = total // 5
    
    parte1 = listado_pdfs[:tamaño_parte]
    parte2 = listado_pdfs[tamaño_parte:2*tamaño_parte]
    parte3 = listado_pdfs[2*tamaño_parte:3*tamaño_parte]
    parte4 = listado_pdfs[3*tamaño_parte:4*tamaño_parte]
    parte5 = listado_pdfs[4*tamaño_parte:]
    
    return parte1, parte2, parte3, parte4, parte5

# %%
bucket_name = 'tfm_javi'

# %%
# Definir los esquemas de respuesta
response_schemas = [
    ResponseSchema(name="numero_expediente", description="Número de Expediente, ejemplo SD2023/0000046"),
    ResponseSchema(name="resolucion", description="Una de las siguientes opciones: negada_con_oposicion, negada_sin_oposicion, aprobada_sin_oposicion, aprobada_con_oposición"),
    ResponseSchema(name="numero_de_resolución", description="Número entero de la resolución, ejemplo 2195"),
    ResponseSchema(name="denominacion", description="Nombre de la empresa que solicita el registro de la marca"),
    ResponseSchema(name="vigencia", description="Fecha en que expira la vigencia del registro, o texto si es negada o vencida"),
    ResponseSchema(name="titular", description="Titular de la marca que intenta registrar"),
    ResponseSchema(name="clase", description="Número o lista de números de la Clasificación Internacional de Niza, por ejemplo [42, 35, 27]"),
    ResponseSchema(name="gaceta", description="Número de la gaceta de Propiedad Industrial donde se publica"),
    ResponseSchema(name="tipo", description="Tipo de registro que se intenta realizar, por ejemplo Mixta, Nominativa, Figurativa"),
    ResponseSchema(name="fecha_solicitud", description="Fecha de presentación de la solicitud"),
    ResponseSchema(name="fecha_resolucion", description="Fecha de resolución"),
    ResponseSchema(name="nombre_opositor", description="Nombre de la empresa que se opone a la publicación"),
    ResponseSchema(name="signo_opositor_opositores", description="Signo o signos de los opositores en conflicto"),
    ResponseSchema(name="argumento_oposición", description="Argumentos en los que se basa para oponerse al registro y artículos en los que se apoya"),
    ResponseSchema(name="explicacion_argumentos_oposicion", description="Breve resumen y explicación de los argumentos de la oposición"),
    ResponseSchema(name="resolucion_organismo", description="Resolución del organismo competente, por ejemplo: 'DENIEGA el registro de la marca PAPELES LA FAVORITA (Mixta)'")
]

# %%
output_parser = StructuredOutputParser.from_response_schemas(response_schemas)
format_instructions = output_parser.get_format_instructions()
# Escapar las llaves para evitar la interpretación de variables
format_instructions = format_instructions.replace("{", "{{").replace("}", "}}")

# %%
system_prompt = """
Eres un Experto abogado Colombiano en analizar resoluciones del SIC (Superintendencia de Industria y Comercio de Colombia),en el ámbito de registro de marcas y lemas.
quiero que extraigas el numero de Expediente, la resolución del conflicto, el numero de la resolución, el nombre de la marca que intenta registrarse, el titular que intenta registrar la marca, el numero de clase que intenta registrar, 
el numero de la gaceta en que ha sido publicada, la fecha de solicitud de registro, nombre de la empresa opositora, el titular de la empresa que se opone si aparece, y los argumentos de derecho en los que se apoya el opositor.
"""
human_prompt = f"""Extrae la información indicada en DATOS a partir del TEXTO de la resolución

TEXT
---
\n\n{{contenido_pdf}}
---

DATOS
{format_instructions}
"""

# %%
prompt = ChatPromptTemplate.from_messages([
    SystemMessagePromptTemplate.from_template(system_prompt),
    HumanMessagePromptTemplate.from_template(human_prompt),
])

# %%
# Define tu LLM 
llm = ChatVertexAI(
    model="gemini-1.5-pro-001"
      #verificar la relacion megas tokens  
)

# %%
chain = LLMChain(llm=llm, prompt=prompt, output_parser=output_parser)
# Out:
# C:\Users\javie\AppData\Local\Temp\ipykernel_9940\2259571032.py:1: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(llm=llm, prompt=prompt, output_parser=output_parser)

# %%
res = chain.invoke({"contenido_pdf": contenido_pdf})

# Parsear la respuesta
#parsed_output = output_parser.parse(res)
# Out:
# {'contenido_pdf': 'REPÚBLICA DE COLOMBIA\nSUPERINTENDENCIA DE INDUSTRIA Y COMERCIO \nResolución N° 8535\nRef. Expediente N° SD2021/0041386\nPágina 1 de 5Ref. Reg. Internacional N° 1588498\nPor la cual se niega un registro \nLA DIRECTORA DE SIGNOS DISTINTIVOS (E)\nen ejercicio de sus facultades legales y,\nCONSIDERANDO\nPRIMERO: Que por escrito presentado ante la Oficina Internacional el día 27 de \nnoviembre de 2020 y radicada ante la Superintendencia de Industria y Comercio el día 29 \nde abril de 2021, ORICA INTERNATIONAL PTE. LTD., solicitó el registro de la Marca 4D \n(Mixta) para distinguir productos y servicios comprendidos en las clases 1, 7, 9, 12, 13, 37 \ny 42 de la Clasificación Internacional de Niza1. \nSEGUNDO: Que publicado en la Gaceta de Propiedad Industrial No. 976, no se \npresentaron oposiciones por parte de terceros.\nTERCERO: Que atendiendo las disposiciones establecidas en la Decisión 486 de la \n1 1: Productos químicos utilizados en las industrias de minería, explotación de canteras y construcción; productos químicos que \ncontienen nitrógeno, incluido nitrato de amonio.\n7: Aparatos de minería, explotación de canteras y construcción; máquinas de minería, explotación de canteras y construcción; aparatos \npara el tratamiento químico; máquinas y aparatos para el tratamiento, la producción y la distribución de productos químicos para la \nminería, la explotación de canteras y la construcción y compuestos químicos, incluidos los compuestos explosivos.\n9: Aparatos científicos, a saber, instrumentos de medición, señalización y detección o comprobación, a saber, dispositivos electrónicos \nde registro y transmisión de datos para comprobar, registrar e informar sobre los datos o las condiciones de los pozos de explosión, \nlos dispositivos de iniciación de las explosiones y la función de los explosivos, detonaciones en forma de explosiones, identificación, \nposicionamiento, disparos e inventarios; aparatos de grabación de datos, a saber, ordenadores; dispositivos periféricos informáticos, \na saber, monitores, impresoras, teclados, unidades de disco duro, CD vírgenes, DVD vírgenes, unidades flash, módems, reproductores \nde CD y DVD; software informático, a saber, software informático para el diseño de detonaciones, el procesamiento de datos de \ndetonaciones y el análisis de detonaciones, así como el uso y el funcionamiento de los dispositivos de prueba, registro, conexión, \ntransmisión e iniciación utilizados en la programación de detonaciones y explosiones, para la gestión de los resultados de las \ndetonaciones (explosiones), la programación de las detonaciones (explosiones) y para el registro, la recuperación, la elaboración de \ninformes, el almacenamiento y el análisis de la información de determinadas detonaciones (explosiones) finalizadas; sistemas de \ngestión de datos compuestos de hardware y software de gestión, registro, elaboración de informes, recuperación, almacenamiento y \nanálisis de datos e información en relación con detonaciones en forma de explosiones y para el uso y el funcionamiento de dispositivos \nde prueba, registro, conexión, transmisión e iniciación utilizados en la programación de detonaciones y explosiones; software de \ncomunicación, a saber, software de comunicación para conectar redes de área local, redes de área amplia y redes informáticas \nglobales, todo ello para diseño de detonaciones y gestión, registro, elaboración de informes, recuperación, almacenamiento y análisis \nde datos e información en relación con detonaciones en forma de explosiones y para el uso y el funcionamiento de dispositivos de \nprueba, registro, conexión, transmisión e iniciación utilizados en la programación de detonaciones y explosiones; software para el \ndiseño de detonaciones, la programación de detonaciones, el procesamiento de datos de detonaciones y el análisis de los resultados \nde detonaciones; aparatos, instrumentos y equipos electrónicos, a saber, módulos electrónicos de cronometraje ...

# %%
res
# Out:
# {'contenido_pdf': 'REPÚBLICA DE COLOMBIA\nSUPERINTENDENCIA DE INDUSTRIA Y COMERCIO \nResolución N° 8535\nRef. Expediente N° SD2021/0041386\nPágina 1 de 5Ref. Reg. Internacional N° 1588498\nPor la cual se niega un registro \nLA DIRECTORA DE SIGNOS DISTINTIVOS (E)\nen ejercicio de sus facultades legales y,\nCONSIDERANDO\nPRIMERO: Que por escrito presentado ante la Oficina Internacional el día 27 de \nnoviembre de 2020 y radicada ante la Superintendencia de Industria y Comercio el día 29 \nde abril de 2021, ORICA INTERNATIONAL PTE. LTD., solicitó el registro de la Marca 4D \n(Mixta) para distinguir productos y servicios comprendidos en las clases 1, 7, 9, 12, 13, 37 \ny 42 de la Clasificación Internacional de Niza1. \nSEGUNDO: Que publicado en la Gaceta de Propiedad Industrial No. 976, no se \npresentaron oposiciones por parte de terceros.\nTERCERO: Que atendiendo las disposiciones establecidas en la Decisión 486 de la \n1 1: Productos químicos utilizados en las industrias de minería, explotación de canteras y construcción; productos químicos que \ncontienen nitrógeno, incluido nitrato de amonio.\n7: Aparatos de minería, explotación de canteras y construcción; máquinas de minería, explotación de canteras y construcción; aparatos \npara el tratamiento químico; máquinas y aparatos para el tratamiento, la producción y la distribución de productos químicos para la \nminería, la explotación de canteras y la construcción y compuestos químicos, incluidos los compuestos explosivos.\n9: Aparatos científicos, a saber, instrumentos de medición, señalización y detección o comprobación, a saber, dispositivos electrónicos \nde registro y transmisión de datos para comprobar, registrar e informar sobre los datos o las condiciones de los pozos de explosión, \nlos dispositivos de iniciación de las explosiones y la función de los explosivos, detonaciones en forma de explosiones, identificación, \nposicionamiento, disparos e inventarios; aparatos de grabación de datos, a saber, ordenadores; dispositivos periféricos informáticos, \na saber, monitores, impresoras, teclados, unidades de disco duro, CD vírgenes, DVD vírgenes, unidades flash, módems, reproductores \nde CD y DVD; software informático, a saber, software informático para el diseño de detonaciones, el procesamiento de datos de \ndetonaciones y el análisis de detonaciones, así como el uso y el funcionamiento de los dispositivos de prueba, registro, conexión, \ntransmisión e iniciación utilizados en la programación de detonaciones y explosiones, para la gestión de los resultados de las \ndetonaciones (explosiones), la programación de las detonaciones (explosiones) y para el registro, la recuperación, la elaboración de \ninformes, el almacenamiento y el análisis de la información de determinadas detonaciones (explosiones) finalizadas; sistemas de \ngestión de datos compuestos de hardware y software de gestión, registro, elaboración de informes, recuperación, almacenamiento y \nanálisis de datos e información en relación con detonaciones en forma de explosiones y para el uso y el funcionamiento de dispositivos \nde prueba, registro, conexión, transmisión e iniciación utilizados en la programación de detonaciones y explosiones; software de \ncomunicación, a saber, software de comunicación para conectar redes de área local, redes de área amplia y redes informáticas \nglobales, todo ello para diseño de detonaciones y gestión, registro, elaboración de informes, recuperación, almacenamiento y análisis \nde datos e información en relación con detonaciones en forma de explosiones y para el uso y el funcionamiento de dispositivos de \nprueba, registro, conexión, transmisión e iniciación utilizados en la programación de detonaciones y explosiones; software para el \ndiseño de detonaciones, la programación de detonaciones, el procesamiento de datos de detonaciones y el análisis de los resultados \nde detonaciones; aparatos, instrumentos y equipos electrónicos, a saber, módulos electrónicos de cronometraje ...
#  'text': {'numero_expediente': 'SD2021/0041386',
#   'resolucion': 'negada_sin_oposicion',
#   'numero_de_resolución': '8535',
#   'denominacion': '4D',
#   'vigencia': 'negada',
#   'titular': 'ORICA INTERNATIONAL PTE. LTD.',
#   'clase': '[1, 7, 9, 12, 13, 37, 42]',
#   'gaceta': '976',
#   'tipo': 'Mixta',
#   'fecha_solicitud': '29 de abril de 2021',
#   'fecha_resolucion': '27 de febrero de 2023',
#   'nombre_opositor': '',
#   'signo_opositor_opositores': '',
#   'argumento_oposición': 'Artículo 135 literal b) de la Decisión 486',
#   'explicacion_argumentos_oposicion': 'La marca solicitada carece de distintividad, ya que no permite al consumidor identificar un producto o servicio específico ni atribuirle un origen empresarial. El signo "4D" se considera descriptivo para productos y servicios relacionados con proyectos de ingeniería y minería, aludiendo a una tecnología de optimización del agua en procesos mineros.',
#   'resolucion_organismo': 'NIEGA el registro de la Marca 4D (Mixta)'}}

# %%
# Obtener la lista de PDFs
listado_pdfs = listar_pdfs(bucket_name)

# %%
len(listado_pdfs)
# Out:
# 12786

# %%
parte1, parte2, parte3, parte4, parte5 = dividir_lista_pdfs(listado_pdfs)

# %%
parte1
# Out:
# ['gs://tfm_javi/CCO-14258446.pdf',
#  'gs://tfm_javi/CCO-15006549.pdf',
#  'gs://tfm_javi/CCO-15030961.pdf',
#  'gs://tfm_javi/CCO-15036335.pdf',
#  'gs://tfm_javi/CCO-15036379.pdf',
#  'gs://tfm_javi/CCO-15068367.pdf',
#  'gs://tfm_javi/CCO-15074926.pdf',
#  'gs://tfm_javi/CCO-15078424.pdf',
#  'gs://tfm_javi/CCO-15115149.pdf',
#  'gs://tfm_javi/CCO-15121325.pdf',
#  'gs://tfm_javi/CCO-15121347.pdf',
#  'gs://tfm_javi/CCO-15150860.pdf',
#  'gs://tfm_javi/CCO-15169411.pdf',
#  'gs://tfm_javi/CCO-15169425.pdf',
#  'gs://tfm_javi/CCO-15175257.pdf',
#  'gs://tfm_javi/CCO-15175281.pdf',
#  'gs://tfm_javi/CCO-15213225.pdf',
#  'gs://tfm_javi/CCO-15213227.pdf',
#  'gs://tfm_javi/CCO-15213269.pdf',
#  'gs://tfm_javi/CCO-15233002.pdf',
#  'gs://tfm_javi/CCO-15233023.pdf',
#  'gs://tfm_javi/CCO-15233036.pdf',
#  'gs://tfm_javi/CCO-15244609.pdf',
#  'gs://tfm_javi/CCO-15244658.pdf',
#  'gs://tfm_javi/CCO-15244663.pdf',
#  'gs://tfm_javi/CCO-15244697.pdf',
#  'gs://tfm_javi/CCO-15244792.pdf',
#  'gs://tfm_javi/CCO-15251313.pdf',
#  'gs://tfm_javi/CCO-15251385.pdf',
#  'gs://tfm_javi/CCO-15251386.pdf',
#  'gs://tfm_javi/CCO-15258013.pdf',
#  'gs://tfm_javi/CCO-15258019.pdf',
#  'gs://tfm_javi/CCO-15263488.pdf',
#  'gs://tfm_javi/CCO-15270361.pdf',
#  'gs://tfm_javi/CCO-15270414.pdf',
#  'gs://tfm_javi/CCO-15275283.pdf',
#  'gs://tfm_javi/CCO-15275285.pdf',
#  'gs://tfm_javi/CCO-15288051.pdf',
#  'gs://tfm_javi/CCO-15288065.pdf',
#  'gs://tfm_javi/CCO-15299296.pdf',
#  'gs://tfm_javi/CCO-15312066.pdf',
#  'gs://tfm_javi/CCO-15312087.pdf',
#  'gs://tfm_javi/CCO-15312156.pdf',
#  'gs://tfm_javi/CCO-16007482.pdf',
#  'gs://tfm_javi/CCO-16016951.pdf',
#  'gs://tfm_javi/CCO-16019096.pdf',
#  'gs://tfm_javi/CCO-16019119.pdf',
#  'gs://tfm_javi/CCO-16025290.pdf',
#  'gs://tfm_javi/CCO-16025304.pdf',
#  'gs://tfm_javi/CCO-16025318.pdf',
#  'gs://tfm_javi/CCO-16025326.pdf',
#  'gs://tfm_javi/CCO-16025363.pdf',
#  'gs://tfm_javi/CCO-16033090.pdf',
#  'gs://tfm_javi/CCO-16040380.pdf',
#  'gs://tfm_javi/CCO-16040384.pdf',
#  'gs://tfm_javi/CCO-16040439.pdf',
#  'gs://tfm_javi/CCO-16040442.pdf',
#  'gs://tfm_javi/CCO-16047884.pdf',
#  'gs://tfm_javi/CCO-16047894.pdf',
#  'gs://tfm_javi/CCO-16047961.pdf',
#  'gs://tfm_javi/CCO-16047967.pdf',
#  'gs://tfm_javi/CCO-16054794.pdf',
#  'gs://tfm_javi/CCO-16054827.pdf',
#  'gs://tfm_javi/CCO-16054835.pdf',
#  'gs://tfm_javi/CCO-16061575.pdf',
#  'gs://tfm_javi/CCO-16061604.pdf',
#  'gs://tfm_javi/CCO-16061648.pdf',
#  'gs://tfm_javi/CCO-16068594.pdf',
#  'gs://tfm_javi/CCO-16074546.pdf',
#  'gs://tfm_javi/CCO-16079286.pdf',
#  'gs://tfm_javi/CCO-16079347.pdf',
#  'gs://tfm_javi/CCO-16094041.pdf',
#  'gs://tfm_javi/CCO-16094042.pdf',
#  'gs://tfm_javi/CCO-16108179.pdf',
#  'gs://tfm_javi/CCO-16108189.pdf',
#  'gs://tfm_javi/CCO-16131071.pdf',
#  'gs://tfm_javi/CCO-16138075.pdf',
#  'gs://tfm_javi/CCO-16138089.pdf',
#  'gs://tfm_javi/CCO-16151400.pdf',
#  'gs://tfm_javi/CCO-16151426.pdf',
#  'gs://tfm_javi/CCO-16166598.pdf',
#  'gs://tfm_javi/CCO-16166617.pdf',
#  'gs://tfm_javi/CCO-16166621.pdf',
#  'gs://tfm_javi/CCO-16166634.pdf',
#  'gs://tfm_javi/CCO-16166640.pdf',
#  'gs://tfm_javi/CCO-16175013.pdf',
#  'gs://tfm_javi/CCO-16175015.pdf',
#  'gs://tfm_javi/CCO-SD2016-0000507.pdf',
#  'gs://tfm_javi/CCO-SD2016-0000517.pdf',
#  'gs://tfm_javi/CCO-SD2016-0000579.pdf',
#  'gs://tfm_javi/CCO-SD2016-0000604.pdf',
#  'gs://tfm_javi/CCO-SD2016-0000627.pdf',
#  'gs://tfm_javi/CCO-SD2016-0000655.pdf',
#  'gs://tfm_javi/CCO-SD2016-0001186.pdf',
#  'gs://tfm_javi/CCO-SD2016-0008071.pdf',
#  'gs://tfm_javi/CCO-SD2016-0012522.pdf',
#  'gs://tfm_javi/CCO-SD2016-0015628.pdf',
#  'gs://tfm_javi/CCO-SD2016-0025203.pdf',
#  'gs://tfm_javi/CCO-SD2016-0029384.pdf',
#  'gs://tfm_javi/CCO-SD2016-0032011.pdf',
#  'gs://tfm_javi/CCO-SD2016-0034603.pdf',
#  'gs://tfm_javi/CCO-SD2016-0036847.pdf',
#  'gs://tfm_javi/CCO-SD2016-0036853.pdf',
#  'gs://tfm_javi/CCO-SD2016-0038572.pdf',
#  'gs://tfm_javi/CCO-SD2016-0038637.pdf',
#  'gs://tfm_javi/CCO-SD2016-0038666.pdf',
#  'gs://tfm_javi/CCO-SD2016-0040722.pdf',
#  'gs://tfm_javi/CCO-SD2016-0040799.pdf',
#  'gs://tfm_javi/CCO-SD2016-0042846.pdf',
#  'gs://tfm_javi/CCO-SD2016-0042893.pdf',
#  'gs://tfm_javi/CCO-SD2016-0046367.pdf',
#  'gs://tfm_javi/CCO-SD2016-0046452.pdf',
#  'gs://tfm_javi/CCO-SD2016-0048364.pdf',
#  'gs://tfm_javi/CCO-SD2016-0048394.pdf',
#  'gs://tfm_javi/CCO-SD2016-0048444.pdf',
#  'gs://tfm_javi/CCO-SD2016-0054330.pdf',
#  'gs://tfm_javi/CCO-SD2016-0054391.pdf',
#  'gs://tfm_javi/CCO-SD2016-0054393.pdf',
#  'gs://tfm_javi/CCO-SD2016-0058817.pdf',
#  'gs://tfm_javi/CCO-SD2016-0058835.pdf',
#  'gs://tfm_javi/CCO-SD2016-0058870.pdf',
#  'gs://tfm_javi/CCO-SD2016-0058878.pdf',
#  'gs://tfm_javi/CCO-SD2017-0004849.pdf',
#  'gs://tfm_javi/CCO-SD2017-0007023.pdf',
#  'gs://tfm_javi/CCO-SD2017-0010828.pdf',
#  'gs://tfm_javi/CCO-SD2017-0010911.pdf',
#  'gs://tfm_javi/CCO-SD2017-0017183.pdf',
#  'gs://tfm_javi/CCO-SD2017-0019080.pdf',
#  'gs://tfm_javi/CCO-SD2017-0025029.pdf',
#  'gs://tfm_javi/CCO-SD2017-0027127.pdf',
#  'gs://tfm_javi/CCO-SD2017-0042575.pdf',
#  'gs://tfm_javi/CCO-SD2017-0063539.pdf',
#  'gs://tfm_javi/CCO-SD2017-0071217.pdf',
#  'gs://tfm_javi/CCO-SD2017-0073500.pdf',
#  'gs://tfm_javi/CCO-SD2017-0075440.pdf',
#  'gs://tfm_javi/CCO-SD2017-0075494.pdf',
#  'gs://tfm_javi/CCO-SD2017-0077281.pdf',
#  'gs://tfm_javi/CCO-SD2017-0089407.pdf',
#  'gs://tfm_javi/CCO-SD2018-0005394.pdf',
#  'gs://tfm_javi/CCO-SD2018-0018229.pdf',
#  'gs://tfm_javi/CCO-SD2018-0036206.pdf',
#  'gs://tfm_javi/CCO-SD2018-0036278.pdf',
#  'gs://tfm_javi/CCO-SD2018-0041688.pdf',
#  'gs://tfm_javi/CCO-SD2018-0046490.pdf',
#  'gs://tfm_javi/CCO-SD2018-0048713.pdf',
#  'gs://tfm_javi/CCO-SD2018-0051118.pdf',
#  'gs://tfm_javi/CCO-SD2018-0054269.pdf',
#  'gs://tfm_javi/CCO-SD2018-0057200.pdf',
#  'gs://tfm_javi/CCO-SD2018-0057205.pdf',
#  'gs://tfm_javi/CCO-SD2018-0057225.pdf',
#  'gs://tfm_javi/CCO-SD2018-0058801.pdf',
#  'gs://tfm_javi/CCO-SD2018-0058844.pdf',
#  'gs://tfm_javi/CCO-SD2018-0058888.pdf',
#  'gs://tfm_javi/CCO-SD2018-0058894.pdf',
#  'gs://tfm_javi/CCO-SD2018-0058898.pdf',
#  'gs://tfm_javi/CCO-SD2018-0060677.pdf',
#  'gs://tfm_javi/CCO-SD2018-0063147.pdf',
#  'gs://tfm_javi/CCO-SD2018-0063185.pdf',
#  'gs://tfm_javi/CCO-SD2018-0063202.pdf',
#  'gs://tfm_javi/CCO-SD2018-0063219.pdf',
#  'gs://tfm_javi/CCO-SD2018-0064313.pdf',
#  'gs://tfm_javi/CCO-SD2018-0064340.pdf',
#  'gs://tfm_javi/CCO-SD2018-0066286.pdf',
#  'gs://tfm_javi/CCO-SD2018-0066307.pdf',
#  'gs://tfm_javi/CCO-SD2018-0066336.pdf',
#  'gs://tfm_javi/CCO-SD2018-0067689.pdf',
#  'gs://tfm_javi/CCO-SD2018-0067738.pdf',
#  'gs://tfm_javi/CCO-SD2018-0069984.pdf',
#  'gs://tfm_javi/CCO-SD2018-0072053.pdf',
#  'gs://tfm_javi/CCO-SD2018-0072057.pdf',
#  'gs://tfm_javi/CCO-SD2018-0072092.pdf',
#  'gs://tfm_javi/CCO-SD2018-0073908.pdf',
#  'gs://tfm_javi/CCO-SD2018-0073954.pdf',
#  'gs://tfm_javi/CCO-SD2018-0073955.pdf',
#  'gs://tfm_javi/CCO-SD2018-0073999.pdf',
#  'gs://tfm_javi/CCO-SD2018-0074004.pdf',
#  'gs://tfm_javi/CCO-SD2018-0075949.pdf',
#  'gs://tfm_javi/CCO-SD2018-0077917.pdf',
#  'gs://tfm_javi/CCO-SD2018-0080189.pdf',
#  'gs://tfm_javi/CCO-SD2018-0082412.pdf',
#  'gs://tfm_javi/CCO-SD2018-0082417.pdf',
#  'gs://tfm_javi/CCO-SD2018-0082437.pdf',
#  'gs://tfm_javi/CCO-SD2018-0084348.pdf',
#  'gs://tfm_javi/CCO-SD2018-0086340.pdf',
#  'gs://tfm_javi/CCO-SD2018-0086363.pdf',
#  'gs://tfm_javi/CCO-SD2018-0088639.pdf',
#  'gs://tfm_javi/CCO-SD2018-0090372.pdf',
#  'gs://tfm_javi/CCO-SD2018-0090394.pdf',
#  'gs://tfm_javi/CCO-SD2018-0094050.pdf',
#  'gs://tfm_javi/CCO-SD2018-0094123.pdf',
#  'gs://tfm_javi/CCO-SD2018-0096233.pdf',
#  'gs://tfm_javi/CCO-SD2018-0096238.pdf',
#  'gs://tfm_javi/CCO-SD2018-0096241.pdf',
#  'gs://tfm_javi/CCO-SD2018-0096349.pdf',
#  'gs://tfm_javi/CCO-SD2018-0098769.pdf',
#  'gs://tfm_javi/CCO-SD2018-0098817.pdf',
#  'gs://tfm_javi/CCO-SD2018-0100913.pdf',
#  'gs://tfm_javi/CCO-SD2018-0105204.pdf',
#  'gs://tfm_javi/CCO-SD2019-0001281.pdf',
#  'gs://tfm_javi/CCO-SD2019-0002868.pdf',
#  'gs://tfm_javi/CCO-SD2019-0007027.pdf',
#  'gs://tfm_javi/CCO-SD2019-0007035.pdf',
#  'gs://tfm_javi/CCO-SD2019-0007054.pdf',
#  'gs://tfm_javi/CCO-SD2019-0007075.pdf',
#  'gs://tfm_javi/CCO-SD2019-0009668.pdf',
#  'gs://tfm_javi/CCO-SD2019-0009672.pdf',
#  'gs://tfm_javi/CCO-SD2019-0013817.pdf',
#  'gs://tfm_javi/CCO-SD2019-0013843.pdf',
#  'gs://tfm_javi/CCO-SD2019-0013860.pdf',
#  'gs://tfm_javi/CCO-SD2019-0013880.pdf',
#  'gs://tfm_javi/CCO-SD2019-0017053.pdf',
#  'gs://tfm_javi/CCO-SD2019-0017070.pdf',
#  'gs://tfm_javi/CCO-SD2019-0019101.pdf',
#  'gs://tfm_javi/CCO-SD2019-0019161.pdf',
#  'gs://tfm_javi/CCO-SD2019-0019177.pdf',
#  'gs://tfm_javi/CCO-SD2019-0023181.pdf',
#  'gs://tfm_javi/CCO-SD2019-0023191.pdf',
#  'gs://tfm_javi/CCO-SD2019-0025406.pdf',
#  'gs://tfm_javi/CCO-SD2019-0025411.pdf',
#  'gs://tfm_javi/CCO-SD2019-0025415.pdf',
#  'gs://tfm_javi/CCO-SD2019-0025437.pdf',
#  'gs://tfm_javi/CCO-SD2019-0026849.pdf',
#  'gs://tfm_javi/CCO-SD2019-0026857.pdf',
#  'gs://tfm_javi/CCO-SD2019-0026890.pdf',
#  'gs://tfm_javi/CCO-SD2019-0029089.pdf',
#  'gs://tfm_javi/CCO-SD2019-0030345.pdf',
#  'gs://tfm_javi/CCO-SD2019-0031227.pdf',
#  'gs://tfm_javi/CCO-SD2019-0031244.pdf',
#  'gs://tfm_javi/CCO-SD2019-0031266.pdf',
#  'gs://tfm_javi/CCO-SD2019-0033098.pdf',
#  'gs://tfm_javi/CCO-SD2019-0034353.pdf',
#  'gs://tfm_javi/CCO-SD2019-0036280.pdf',
#  'gs://tfm_javi/CCO-SD2019-0038268.pdf',
#  'gs://tfm_javi/CCO-SD2019-0040403.pdf',
#  'gs://tfm_javi/CCO-SD2019-0040431.pdf',
#  'gs://tfm_javi/CCO-SD2019-0041297.pdf',
#  'gs://tfm_javi/CCO-SD2019-0042704.pdf',
#  'gs://tfm_javi/CCO-SD2019-0042754.pdf',
#  'gs://tfm_javi/CCO-SD2019-0045077.pdf',
#  'gs://tfm_javi/CCO-SD2019-0045103.pdf',
#  'gs://tfm_javi/CCO-SD2019-0045109.pdf',
#  'gs://tfm_javi/CCO-SD2019-0046666.pdf',
#  'gs://tfm_javi/CCO-SD2019-0046716.pdf',
#  'gs://tfm_javi/CCO-SD2019-0049967.pdf',
#  'gs://tfm_javi/CCO-SD2019-0049975.pdf',
#  'gs://tfm_javi/CCO-SD2019-0052344.pdf',
#  'gs://tfm_javi/CCO-SD2019-0052382.pdf',
#  'gs://tfm_javi/CCO-SD2019-0052391.pdf',
#  'gs://tfm_javi/CCO-SD2019-0054012.pdf',
#  'gs://tfm_javi/CCO-SD2019-0054058.pdf',
#  'gs://tfm_javi/CCO-SD2019-0056144.pdf',
#  'gs://tfm_javi/CCO-SD2019-0056148.pdf',
#  'gs://tfm_javi/CCO-SD2019-0056194.pdf',
#  'gs://tfm_javi/CCO-SD2019-0058503.pdf',
#  'gs://tfm_javi/CCO-SD2019-0060516.pdf',
#  'gs://tfm_javi/CCO-SD2019-0063166.pdf',
#  'gs://tfm_javi/CCO-SD2019-0065718.pdf',
#  'gs://tfm_javi/CCO-SD2019-0065719.pdf',
#  'gs://tfm_javi/CCO-SD2019-0065720.pdf',
#  'gs://tfm_javi/CCO-SD2019-0067238.pdf',
#  'gs://tfm_javi/CCO-SD2019-0067268.pdf',
#  'gs://tfm_javi/CCO-SD2019-0067286.pdf',
#  'gs://tfm_javi/CCO-SD2019-0067306.pdf',
#  'gs://tfm_javi/CCO-SD2019-0067321.pdf',
#  'gs://tfm_javi/CCO-SD2019-0067326.pdf',
#  'gs://tfm_javi/CCO-SD2019-0069870.pdf',
#  'gs://tfm_javi/CCO-SD2019-0069952.pdf',
#  'gs://tfm_javi/CCO-SD2019-0071613.pdf',
#  'gs://tfm_javi/CCO-SD2019-0071622.pdf',
#  'gs://tfm_javi/CCO-SD2019-0078049.pdf',
#  'gs://tfm_javi/CCO-SD2019-0080271.pdf',
#  'gs://tfm_javi/CCO-SD2019-0080301.pdf',
#  'gs://tfm_javi/CCO-SD2019-0080357.pdf',
#  'gs://tfm_javi/CCO-SD2019-0082541.pdf',
#  'gs://tfm_javi/CCO-SD2019-0084749.pdf',
#  'gs://tfm_javi/CCO-SD2019-0086857.pdf',
#  'gs://tfm_javi/CCO-SD2019-0088455.pdf',
#  'gs://tfm_javi/CCO-SD2019-0088464.pdf',
#  'gs://tfm_javi/CCO-SD2019-0090527.pdf',
#  'gs://tfm_javi/CCO-SD2019-0094291.pdf',
#  'gs://tfm_javi/CCO-SD2019-0094336.pdf',
#  'gs://tfm_javi/CCO-SD2019-0096234.pdf',
#  'gs://tfm_javi/CCO-SD2019-0096258.pdf',
#  'gs://tfm_javi/CCO-SD2019-0098460.pdf',
#  'gs://tfm_javi/CCO-SD2019-0098792.pdf',
#  'gs://tfm_javi/CCO-SD2019-0100585.pdf',
#  'gs://tfm_javi/CCO-SD2019-0102675.pdf',
#  'gs://tfm_javi/CCO-SD2019-0102683.pdf',
#  'gs://tfm_javi/CCO-SD2019-0102717.pdf',
#  'gs://tfm_javi/CCO-SD2019-0102728.pdf',
#  'gs://tfm_javi/CCO-SD2019-0104782.pdf',
#  'gs://tfm_javi/CCO-SD2019-0108879.pdf',
#  'gs://tfm_javi/CCO-SD2019-0108944.pdf',
#  'gs://tfm_javi/CCO-SD2020-0000095.pdf',
#  'gs://tfm_javi/CCO-SD2020-0001151.pdf',
#  'gs://tfm_javi/CCO-SD2020-0001160.pdf',
#  'gs://tfm_javi/CCO-SD2020-0001173.pdf',
#  'gs://tfm_javi/CCO-SD2020-0002561.pdf',
#  'gs://tfm_javi/CCO-SD2020-0002589.pdf',
#  'gs://tfm_javi/CCO-SD2020-0004496.pdf',
#  'gs://tfm_javi/CCO-SD2020-0004498.pdf',
#  'gs://tfm_javi/CCO-SD2020-0004504.pdf',
#  'gs://tfm_javi/CCO-SD2020-0004519.pdf',
#  'gs://tfm_javi/CCO-SD2020-0004543.pdf',
#  'gs://tfm_javi/CCO-SD2020-0004558.pdf',
#  'gs://tfm_javi/CCO-SD2020-0008626.pdf',
#  'gs://tfm_javi/CCO-SD2020-0009915.pdf',
#  'gs://tfm_javi/CCO-SD2020-0009952.pdf',
#  'gs://tfm_javi/CCO-SD2020-0009974.pdf',
#  'gs://tfm_javi/CCO-SD2020-0010022.pdf',
#  'gs://tfm_javi/CCO-SD2020-0010029.pdf',
#  'gs://tfm_javi/CCO-SD2020-0011784.pdf',
#  'gs://tfm_javi/CCO-SD2020-0013645.pdf',
#  'gs://tfm_javi/CCO-SD2020-0013677.pdf',
#  'gs://tfm_javi/CCO-SD2020-0013699.pdf',
#  'gs://tfm_javi/CCO-SD2020-0013701.pdf',
#  'gs://tfm_javi/CCO-SD2020-0013711.pdf',
#  'gs://tfm_javi/CCO-SD2020-0016015.pdf',
#  'gs://tfm_javi/CCO-SD2020-0016058.pdf',
#  'gs://tfm_javi/CCO-SD2020-0018239.pdf',
#  'gs://tfm_javi/CCO-SD2020-0018294.pdf',
#  'gs://tfm_javi/CCO-SD2020-0020067.pdf',
#  'gs://tfm_javi/CCO-SD2020-0022577.pdf',
#  'gs://tfm_javi/CCO-SD2020-0023706.pdf',
#  'gs://tfm_javi/CCO-SD2020-0023728.pdf',
#  'gs://tfm_javi/CCO-SD2020-0023743.pdf',
#  'gs://tfm_javi/CCO-SD2020-0023747.pdf',
#  'gs://tfm_javi/CCO-SD2020-0023754.pdf',
#  'gs://tfm_javi/CCO-SD2020-0025270.pdf',
#  'gs://tfm_javi/CCO-SD2020-0025280.pdf',
#  'gs://tfm_javi/CCO-SD2020-0025317.pdf',
#  'gs://tfm_javi/CCO-SD2020-0026852.pdf',
#  'gs://tfm_javi/CCO-SD2020-0026868.pdf',
#  'gs://tfm_javi/CCO-SD2020-0026899.pdf',
#  'gs://tfm_javi/CCO-SD2020-0029180.pdf',
#  'gs://tfm_javi/CCO-SD2020-0029961.pdf',
#  'gs://tfm_javi/CCO-SD2020-0029966.pdf',
#  'gs://tfm_javi/CCO-SD2020-0029969.pdf',
#  'gs://tfm_javi/CCO-SD2020-0030011.pdf',
#  'gs://tfm_javi/CCO-SD2020-0031931.pdf',
#  'gs://tfm_javi/CCO-SD2020-0034846.pdf',
#  'gs://tfm_javi/CCO-SD2020-0034890.pdf',
#  'gs://tfm_javi/CCO-SD2020-0038356.pdf',
#  'gs://tfm_javi/CCO-SD2020-0038900.pdf',
#  'gs://tfm_javi/CCO-SD2020-0041538.pdf',
#  'gs://tfm_javi/CCO-SD2020-0041568.pdf',
#  'gs://tfm_javi/CCO-SD2020-0041588.pdf',
#  'gs://tfm_javi/CCO-SD2020-0041595.pdf',
#  'gs://tfm_javi/CCO-SD2020-0043437.pdf',
#  'gs://tfm_javi/CCO-SD2020-0043439.pdf',
#  'gs://tfm_javi/CCO-SD2020-0043457.pdf',
#  'gs://tfm_javi/CCO-SD2020-0047371.pdf',
#  'gs://tfm_javi/CCO-SD2020-0049347.pdf',
#  'gs://tfm_javi/CCO-SD2020-0049375.pdf',
#  'gs://tfm_javi/CCO-SD2020-0051878.pdf',
#  'gs://tfm_javi/CCO-SD2020-0051921.pdf',
#  'gs://tfm_javi/CCO-SD2020-0056083.pdf',
#  'gs://tfm_javi/CCO-SD2020-0058636.pdf',
#  'gs://tfm_javi/CCO-SD2020-0058702.pdf',
#  'gs://tfm_javi/CCO-SD2020-0058711.pdf',
#  'gs://tfm_javi/CCO-SD2020-0063190.pdf',
#  'gs://tfm_javi/CCO-SD2020-0067698.pdf',
#  'gs://tfm_javi/CCO-SD2020-0067735.pdf',
#  'gs://tfm_javi/CCO-SD2020-0070034.pdf',
#  'gs://tfm_javi/CCO-SD2020-0072428.pdf',
#  'gs://tfm_javi/CCO-SD2020-0072477.pdf',
#  'gs://tfm_javi/CCO-SD2020-0075245.pdf',
#  'gs://tfm_javi/CCO-SD2020-0077672.pdf',
#  'gs://tfm_javi/CCO-SD2020-0077720.pdf',
#  'gs://tfm_javi/CCO-SD2020-0099788.pdf',
#  'gs://tfm_javi/CCO-SD2020-0104932.pdf',
#  'gs://tfm_javi/CCO-SD2021-0000014.pdf',
#  'gs://tfm_javi/CCO-SD2021-0011038.pdf',
#  'gs://tfm_javi/CCO-SD2021-0016944.pdf',
#  'gs://tfm_javi/CCO-SD2021-0031995.pdf',
#  'gs://tfm_javi/CCO-SD2021-0033797.pdf',
#  'gs://tfm_javi/CCO-SD2021-0033850.pdf',
#  'gs://tfm_javi/CCO-SD2021-0036721.pdf',
#  'gs://tfm_javi/CCO-SD2021-0041365.pdf',
#  'gs://tfm_javi/CCO-SD2021-0053090.pdf',
#  'gs://tfm_javi/CCO-SD2021-0057112.pdf',
#  'gs://tfm_javi/CCO-SD2021-0057157.pdf',
#  'gs://tfm_javi/CCO-SD2021-0059546.pdf',
#  'gs://tfm_javi/CCO-SD2021-0062442.pdf',
#  'gs://tfm_javi/CCO-SD2021-0063813.pdf',
#  'gs://tfm_javi/CCO-SD2021-0063816.pdf',
#  'gs://tfm_javi/CCO-SD2021-0063842.pdf',
#  'gs://tfm_javi/CCO-SD2021-0066420.pdf',
#  'gs://tfm_javi/CCO-SD2021-0069046.pdf',
#  'gs://tfm_javi/CCO-SD2021-0071738.pdf',
#  'gs://tfm_javi/CCO-SD2021-0074056.pdf',
#  'gs://tfm_javi/CCO-SD2021-0076237.pdf',
#  'gs://tfm_javi/CCO-SD2021-0076271.pdf',
#  'gs://tfm_javi/CCO-SD2021-0076272.pdf',
#  'gs://tfm_javi/CCO-SD2021-0078028.pdf',
#  'gs://tfm_javi/CCO-SD2021-0078050.pdf',
#  'gs://tfm_javi/CCO-SD2021-0078060.pdf',
#  'gs://tfm_javi/CCO-SD2021-0082856.pdf',
#  'gs://tfm_javi/CCO-SD2021-0085336.pdf',
#  'gs://tfm_javi/CCO-SD2021-0085337.pdf',
#  'gs://tfm_javi/CCO-SD2021-0087766.pdf',
#  'gs://tfm_javi/CCO-SD2021-0092167.pdf',
#  'gs://tfm_javi/CCO-SD2021-0092201.pdf',
#  'gs://tfm_javi/CCO-SD2021-0092227.pdf',
#  'gs://tfm_javi/CCO-SD2021-0092235.pdf',
#  'gs://tfm_javi/CCO-SD2021-0097364.pdf',
#  'gs://tfm_javi/CCO-SD2021-0099109.pdf',
#  'gs://tfm_javi/CCO-SD2021-0099120.pdf',
#  'gs://tfm_javi/CCO-SD2021-0099137.pdf',
#  'gs://tfm_javi/CCO-SD2021-0099179.pdf',
#  'gs://tfm_javi/CCO-SD2021-0102337.pdf',
#  'gs://tfm_javi/CCO-SD2021-0102361.pdf',
#  'gs://tfm_javi/CCO-SD2021-0104172.pdf',
#  'gs://tfm_javi/CCO-SD2021-0104179.pdf',
#  'gs://tfm_javi/CCO-SD2021-0106556.pdf',
#  'gs://tfm_javi/CCO-SD2021-0108627.pdf',
#  'gs://tfm_javi/CCO-SD2021-0108685.pdf',
#  'gs://tfm_javi/CCO-SD2021-0108718.pdf',
#  'gs://tfm_javi/CCO-SD2021-0111765.pdf',
#  'gs://tfm_javi/CCO-SD2021-0111777.pdf',
#  'gs://tfm_javi/CCO-SD2021-0113776.pdf',
#  'gs://tfm_javi/CCO-SD2021-0113856.pdf',
#  'gs://tfm_javi/CCO-SD2021-0113893.pdf',
#  'gs://tfm_javi/CCO-SD2021-0115772.pdf',
#  'gs://tfm_javi/CCO-SD2021-0123431.pdf',
#  'gs://tfm_javi/CCO-SD2021-0123434.pdf',
#  'gs://tfm_javi/CCO-SD2021-0123444.pdf',
#  'gs://tfm_javi/CCO-SD2021-0123448.pdf',
#  'gs://tfm_javi/CCO-SD2021-0123449.pdf',
#  'gs://tfm_javi/CCO-SD2022-0001145.pdf',
#  'gs://tfm_javi/CCO-SD2022-0002318.pdf',
#  'gs://tfm_javi/CCO-SD2022-0009425.pdf',
#  'gs://tfm_javi/CCO-SD2022-0009434.pdf',
#  'gs://tfm_javi/CCO-SD2022-0009448.pdf',
#  'gs://tfm_javi/CCO-SD2022-0011730.pdf',
#  'gs://tfm_javi/CCO-SD2022-0014345.pdf',
#  'gs://tfm_javi/CCO-SD2022-0014349.pdf',
#  'gs://tfm_javi/CCO-SD2022-0014372.pdf',
#  'gs://tfm_javi/CCO-SD2022-0014426.pdf',
#  'gs://tfm_javi/CCO-SD2022-0017188.pdf',
#  'gs://tfm_javi/CCO-SD2022-0020263.pdf',
#  'gs://tfm_javi/CCO-SD2022-0025766.pdf',
#  'gs://tfm_javi/CCO-SD2022-0025804.pdf',
#  'gs://tfm_javi/CCO-SD2022-0025833.pdf',
#  'gs://tfm_javi/CCO-SD2022-0031418.pdf',
#  'gs://tfm_javi/CCO-SD2022-0034077.pdf',
#  'gs://tfm_javi/CCO-SD2022-0036552.pdf',
#  'gs://tfm_javi/CCO-SD2022-0036585.pdf',
#  'gs://tfm_javi/CCO-SD2022-0038857.pdf',
#  'gs://tfm_javi/CCO-SD2022-0038870.pdf',
#  'gs://tfm_javi/CCO-SD2022-0041487.pdf',
#  'gs://tfm_javi/CCO-SD2022-0041496.pdf',
#  'gs://tfm_javi/CCO-SD2022-0044417.pdf',
#  'gs://tfm_javi/CCO-SD2022-0049540.pdf',
#  'gs://tfm_javi/CCO-SD2022-0049624.pdf',
#  'gs://tfm_javi/CCO-SD2022-0052224.pdf',
#  'gs://tfm_javi/CCO-SD2022-0052228.pdf',
#  'gs://tfm_javi/CCO-SD2022-0054807.pdf',
#  'gs://tfm_javi/CCO-SD2022-0057745.pdf',
#  'gs://tfm_javi/CCO-SD2022-0060396.pdf',
#  'gs://tfm_javi/CCO-SD2022-0060403.pdf',
#  'gs://tfm_javi/CCO-SD2022-0063085.pdf',
#  'gs://tfm_javi/CCO-SD2022-0065702.pdf',
#  'gs://tfm_javi/CCO-SD2022-0070993.pdf',
#  'gs://tfm_javi/CCO-SD2022-0071059.pdf',
#  'gs://tfm_javi/CCO-SD2022-0076131.pdf',
#  'gs://tfm_javi/CCO-SD2022-0076155.pdf',
#  'gs://tfm_javi/CCO-SD2022-0076158.pdf',
#  'gs://tfm_javi/CCO-SD2022-0076167.pdf',
#  'gs://tfm_javi/CCO-SD2022-0076179.pdf',
#  'gs://tfm_javi/CCO-SD2022-0078912.pdf',
#  'gs://tfm_javi/CCO-SD2022-0081572.pdf',
#  'gs://tfm_javi/CCO-SD2022-0081591.pdf',
#  'gs://tfm_javi/CCO-SD2022-0081642.pdf',
#  'gs://tfm_javi/CCO-SD2022-0083786.pdf',
#  'gs://tfm_javi/CCO-SD2022-0083789.pdf',
#  'gs://tfm_javi/CCO-SD2022-0087107.pdf',
#  'gs://tfm_javi/CCO-SD2022-0092553.pdf',
#  'gs://tfm_javi/CCO-SD2022-0092554.pdf',
#  'gs://tfm_javi/CCO-SD2022-0097374.pdf',
#  'gs://tfm_javi/CCO-SD2022-0097431.pdf',
#  'gs://tfm_javi/CCO-SD2022-0099899.pdf',
#  'gs://tfm_javi/CCO-SD2022-0099969.pdf',
#  'gs://tfm_javi/CCO-SD2022-0105183.pdf',
#  'gs://tfm_javi/CCO-SD2022-0107682.pdf',
#  'gs://tfm_javi/CCO-SD2022-0107696.pdf',
#  'gs://tfm_javi/CCO-SD2022-0107716.pdf',
#  'gs://tfm_javi/CCO-SD2022-0107727.pdf',
#  'gs://tfm_javi/CCO-SD2022-0107780.pdf',
#  'gs://tfm_javi/CCO-SD2022-0107789.pdf',
#  'gs://tfm_javi/CCO-SD2022-0110474.pdf',
#  'gs://tfm_javi/CCO-SD2022-0110483.pdf',
#  'gs://tfm_javi/CCO-SD2022-0110517.pdf',
#  'gs://tfm_javi/CCO-SD2022-0113479.pdf',
#  'gs://tfm_javi/CCO-SD2022-0113491.pdf',
#  'gs://tfm_javi/CCO-SD2022-0115707.pdf',
#  'gs://tfm_javi/CCO-SD2022-0115723.pdf',
#  'gs://tfm_javi/CCO-SD2022-0115772.pdf',
#  'gs://tfm_javi/CCO-SD2022-0118383.pdf',
#  'gs://tfm_javi/CCO-SD2022-0121377.pdf',
#  'gs://tfm_javi/CCO-SD2022-0124257.pdf',
#  'gs://tfm_javi/CCO-SD2022-0124277.pdf',
#  'gs://tfm_javi/CCO-SD2022-0124310.pdf',
#  'gs://tfm_javi/CCO-SD2022-0127192.pdf',
#  'gs://tfm_javi/CCO-SD2022-0127262.pdf',
#  'gs://tfm_javi/CCO-SD2022-0127273.pdf',
#  'gs://tfm_javi/CCO-SD2022-0133777.pdf',
#  'gs://tfm_javi/CCO-SD2022-0133788.pdf',
#  'gs://tfm_javi/CCO-SD2022-0133794.pdf',
#  'gs://tfm_javi/CCO-SD2022-0133828.pdf',
#  'gs://tfm_javi/CCO-SD2022-0133859.pdf',
#  'gs://tfm_javi/CCO-SD2023-0000515.pdf',
#  'gs://tfm_javi/CCO-SD2023-0001631.pdf',
#  'gs://tfm_javi/CCO-SD2023-0001679.pdf',
#  'gs://tfm_javi/CCO-SD2023-0003478.pdf',
#  'gs://tfm_javi/CCO-SD2023-0003509.pdf',
#  'gs://tfm_javi/CCO-SD2023-0003523.pdf',
#  'gs://tfm_javi/CCO-SD2023-0003532.pdf',
#  'gs://tfm_javi/CCO-SD2023-0009426.pdf',
#  'gs://tfm_javi/CCO-SD2023-0009522.pdf',
#  'gs://tfm_javi/CCO-SD2023-0018491.pdf',
#  'gs://tfm_javi/CCO-SD2023-0018535.pdf',
#  'gs://tfm_javi/CCO-SD2023-0020967.pdf',
#  'gs://tfm_javi/CCO-SD2023-0021019.pdf',
#  'gs://tfm_javi/CCO-SD2023-0023080.pdf',
#  'gs://tfm_javi/CCO-SD2023-0025630.pdf',
#  'gs://tfm_javi/CCO-SD2023-0025640.pdf',
#  'gs://tfm_javi/CCO-SD2023-0027603.pdf',
#  'gs://tfm_javi/CCO-SD2023-0027614.pdf',
#  'gs://tfm_javi/CCO-SD2023-0027676.pdf',
#  'gs://tfm_javi/CCO-SD2023-0028910.pdf',
#  'gs://tfm_javi/CCO-SD2023-0036144.pdf',
#  'gs://tfm_javi/CCO-SD2023-0037842.pdf',
#  'gs://tfm_javi/CCO-SD2023-0038818.pdf',
#  'gs://tfm_javi/CCO-SD2023-0041496.pdf',
#  'gs://tfm_javi/CCO-SD2023-0043530.pdf',
#  'gs://tfm_javi/CCO-SD2023-0051147.pdf',
#  'gs://tfm_javi/CCO-SD2023-0053121.pdf',
#  'gs://tfm_javi/CCO-SD2023-0053177.pdf',
#  'gs://tfm_javi/CCO-SD2023-0053219.pdf',
#  'gs://tfm_javi/CCO-SD2023-0055848.pdf',
#  'gs://tfm_javi/CCO-SD2023-0064089.pdf',
#  'gs://tfm_javi/CCO-SD2023-0064101.pdf',
#  'gs://tfm_javi/CCO-SD2023-0064111.pdf',
#  'gs://tfm_javi/CCO-SD2023-0068430.pdf',
#  'gs://tfm_javi/CCO-SD2023-0070596.pdf',
#  'gs://tfm_javi/CCO-SD2023-0070632.pdf',
#  'gs://tfm_javi/CCO-SD2023-0070639.pdf',
#  'gs://tfm_javi/CCO-SD2023-0073184.pdf',
#  'gs://tfm_javi/CCO-SD2023-0073192.pdf',
#  'gs://tfm_javi/CCO-SD2023-0075406.pdf',
#  'gs://tfm_javi/CCO-SD2023-0078092.pdf',
#  'gs://tfm_javi/CCO-SD2023-0082006.pdf',
#  'gs://tfm_javi/CCO-SD2023-0082028.pdf',
#  'gs://tfm_javi/CCO-SD2023-0082060.pdf',
#  'gs://tfm_javi/CCO-SD2023-0084911.pdf',
#  'gs://tfm_javi/CCO-SD2023-0100616.pdf',
#  'gs://tfm_javi/CCO-SD2023-0100644.pdf',
#  'gs://tfm_javi/CCO-SD2023-0101245.pdf',
#  'gs://tfm_javi/CCO-SD2023-0103690.pdf',
#  'gs://tfm_javi/CCO-SD2023-0106537.pdf',
#  'gs://tfm_javi/CCO-SD2023-0114514.pdf',
#  'gs://tfm_javi/CCO-SD2024-0009958.pdf',
#  'gs://tfm_javi/CSO-12230823.pdf',
#  'gs://tfm_javi/CSO-13183451.pdf',
#  'gs://tfm_javi/CSO-13233694.pdf',
#  'gs://tfm_javi/CSO-13241911.pdf',
#  'gs://tfm_javi/CSO-13241950.pdf',
#  'gs://tfm_javi/CSO-14081299.pdf',
#  'gs://tfm_javi/CSO-14189743.pdf',
#  'gs://tfm_javi/CSO-14218675.pdf',
#  'gs://tfm_javi/CSO-14283486.pdf',
#  'gs://tfm_javi/CSO-14283530.pdf',
#  'gs://tfm_javi/CSO-15036410.pdf',
#  'gs://tfm_javi/CSO-15036421.pdf',
#  'gs://tfm_javi/CSO-15036425.pdf',
#  'gs://tfm_javi/CSO-15068386.pdf',
#  'gs://tfm_javi/CSO-15084617.pdf',
#  'gs://tfm_javi/CSO-15091818.pdf',
#  'gs://tfm_javi/CSO-15099004.pdf',
#  'gs://tfm_javi/CSO-15110180.pdf',
#  'gs://tfm_javi/CSO-15110201.pdf',
#  'gs://tfm_javi/CSO-15115167.pdf',
#  'gs://tfm_javi/CSO-15115178.pdf',
#  'gs://tfm_javi/CSO-15115187.pdf',
#  'gs://tfm_javi/CSO-15115216.pdf',
#  'gs://tfm_javi/CSO-15115220.pdf',
#  'gs://tfm_javi/CSO-15115224.pdf',
#  'gs://tfm_javi/CSO-15121322.pdf',
#  'gs://tfm_javi/CSO-15121330.pdf',
#  'gs://tfm_javi/CSO-15121338.pdf',
#  'gs://tfm_javi/CSO-15121350.pdf',
#  'gs://tfm_javi/CSO-15121354.pdf',
#  'gs://tfm_javi/CSO-15121358.pdf',
#  'gs://tfm_javi/CSO-15121360.pdf',
#  'gs://tfm_javi/CSO-15121362.pdf',
#  'gs://tfm_javi/CSO-15127481.pdf',
#  'gs://tfm_javi/CSO-15127491.pdf',
#  'gs://tfm_javi/CSO-15127517.pdf',
#  'gs://tfm_javi/CSO-15127545.pdf',
#  'gs://tfm_javi/CSO-15132926.pdf',
#  'gs://tfm_javi/CSO-15132934.pdf',
#  'gs://tfm_javi/CSO-15132956.pdf',
#  'gs://tfm_javi/CSO-15132966.pdf',
#  'gs://tfm_javi/CSO-15132972.pdf',
#  'gs://tfm_javi/CSO-15138934.pdf',
#  'gs://tfm_javi/CSO-15138942.pdf',
#  'gs://tfm_javi/CSO-15138946.pdf',
#  'gs://tfm_javi/CSO-15138951.pdf',
#  'gs://tfm_javi/CSO-15138955.pdf',
#  'gs://tfm_javi/CSO-15139007.pdf',
#  'gs://tfm_javi/CSO-15139048.pdf',
#  'gs://tfm_javi/CSO-15139053.pdf',
#  'gs://tfm_javi/CSO-15139055.pdf',
#  'gs://tfm_javi/CSO-15145381.pdf',
#  'gs://tfm_javi/CSO-15150807.pdf',
#  'gs://tfm_javi/CSO-15150814.pdf',
#  'gs://tfm_javi/CSO-15157198.pdf',
#  'gs://tfm_javi/CSO-15157209.pdf',
#  'gs://tfm_javi/CSO-15157224.pdf',
#  'gs://tfm_javi/CSO-15157227.pdf',
#  'gs://tfm_javi/CSO-15157229.pdf',
#  'gs://tfm_javi/CSO-15157243.pdf',
#  'gs://tfm_javi/CSO-15157271.pdf',
#  'gs://tfm_javi/CSO-15157276.pdf',
#  'gs://tfm_javi/CSO-15157281.pdf',
#  'gs://tfm_javi/CSO-15157282.pdf',
#  'gs://tfm_javi/CSO-15157290.pdf',
#  'gs://tfm_javi/CSO-15157302.pdf',
#  'gs://tfm_javi/CSO-15164626.pdf',
#  'gs://tfm_javi/CSO-15164630.pdf',
#  'gs://tfm_javi/CSO-15164660.pdf',
#  'gs://tfm_javi/CSO-15164663.pdf',
#  'gs://tfm_javi/CSO-15169391.pdf',
#  'gs://tfm_javi/CSO-15175227.pdf',
#  'gs://tfm_javi/CSO-15175308.pdf',
#  'gs://tfm_javi/CSO-15175309.pdf',
#  'gs://tfm_javi/CSO-15175324.pdf',
#  'gs://tfm_javi/CSO-15175327.pdf',
#  'gs://tfm_javi/CSO-15182471.pdf',
#  'gs://tfm_javi/CSO-15182473.pdf',
#  'gs://tfm_javi/CSO-15182480.pdf',
#  'gs://tfm_javi/CSO-15182481.pdf',
#  'gs://tfm_javi/CSO-15182515.pdf',
#  'gs://tfm_javi/CSO-15189172.pdf',
#  'gs://tfm_javi/CSO-15189182.pdf',
#  'gs://tfm_javi/CSO-15189192.pdf',
#  'gs://tfm_javi/CSO-15189218.pdf',
#  'gs://tfm_javi/CSO-15193689.pdf',
#  'gs://tfm_javi/CSO-15200233.pdf',
#  'gs://tfm_javi/CSO-15200241.pdf',
#  'gs://tfm_javi/CSO-15200242.pdf',
#  'gs://tfm_javi/CSO-15200256.pdf',
#  'gs://tfm_javi/CSO-15207720.pdf',
#  'gs://tfm_javi/CSO-15213299.pdf',
#  'gs://tfm_javi/CSO-15219566.pdf',
#  'gs://tfm_javi/CSO-15219582.pdf',
#  'gs://tfm_javi/CSO-15219589.pdf',
#  'gs://tfm_javi/CSO-15219595.pdf',
#  'gs://tfm_javi/CSO-15219632.pdf',
#  'gs://tfm_javi/CSO-15227297.pdf',
#  'gs://tfm_javi/CSO-15227349.pdf',
#  'gs://tfm_javi/CSO-15227365.pdf',
#  'gs://tfm_javi/CSO-15232211.pdf',
#  'gs://tfm_javi/CSO-15233001.pdf',
#  'gs://tfm_javi/CSO-15233049.pdf',
#  'gs://tfm_javi/CSO-15233086.pdf',
#  'gs://tfm_javi/CSO-15239404.pdf',
#  'gs://tfm_javi/CSO-15239431.pdf',
#  'gs://tfm_javi/CSO-15239440.pdf',
#  'gs://tfm_javi/CSO-15239444.pdf',
#  'gs://tfm_javi/CSO-15239519.pdf',
#  'gs://tfm_javi/CSO-15244596.pdf',
#  'gs://tfm_javi/CSO-15244625.pdf',
#  'gs://tfm_javi/CSO-15244628.pdf',
#  'gs://tfm_javi/CSO-15244695.pdf',
#  'gs://tfm_javi/CSO-15244743.pdf',
#  'gs://tfm_javi/CSO-15251299.pdf',
#  'gs://tfm_javi/CSO-15251305.pdf',
#  'gs://tfm_javi/CSO-15251318.pdf',
#  'gs://tfm_javi/CSO-15251349.pdf',
#  'gs://tfm_javi/CSO-15251356.pdf',
#  'gs://tfm_javi/CSO-15251369.pdf',
#  'gs://tfm_javi/CSO-15251379.pdf',
#  'gs://tfm_javi/CSO-15251391.pdf',
#  'gs://tfm_javi/CSO-15251400.pdf',
#  'gs://tfm_javi/CSO-15251405.pdf',
#  'gs://tfm_javi/CSO-15257955.pdf',
#  'gs://tfm_javi/CSO-15257971.pdf',
#  'gs://tfm_javi/CSO-15257987.pdf',
#  'gs://tfm_javi/CSO-15257988.pdf',
#  'gs://tfm_javi/CSO-15257994.pdf',
#  'gs://tfm_javi/CSO-15258004.pdf',
#  'gs://tfm_javi/CSO-15258022.pdf',
#  'gs://tfm_javi/CSO-15258029.pdf',
#  'gs://tfm_javi/CSO-15258034.pdf',
#  'gs://tfm_javi/CSO-15263448.pdf',
#  'gs://tfm_javi/CSO-15263451.pdf',
#  'gs://tfm_javi/CSO-15263456.pdf',
#  'gs://tfm_javi/CSO-15263459.pdf',
#  'gs://tfm_javi/CSO-15263468.pdf',
#  'gs://tfm_javi/CSO-15263473.pdf',
#  'gs://tfm_javi/CSO-15263474.pdf',
#  'gs://tfm_javi/CSO-15263477.pdf',
#  'gs://tfm_javi/CSO-15263478.pdf',
#  'gs://tfm_javi/CSO-15263481.pdf',
#  'gs://tfm_javi/CSO-15263490.pdf',
#  'gs://tfm_javi/CSO-15263491.pdf',
#  'gs://tfm_javi/CSO-15263501.pdf',
#  'gs://tfm_javi/CSO-15263516.pdf',
#  'gs://tfm_javi/CSO-15263517.pdf',
#  'gs://tfm_javi/CSO-15263520.pdf',
#  'gs://tfm_javi/CSO-15263524.pdf',
#  'gs://tfm_javi/CSO-15263537.pdf',
#  'gs://tfm_javi/CSO-15270335.pdf',
#  'gs://tfm_javi/CSO-15270349.pdf',
#  'gs://tfm_javi/CSO-15270380.pdf',
#  'gs://tfm_javi/CSO-15270404.pdf',
#  'gs://tfm_javi/CSO-15270406.pdf',
#  'gs://tfm_javi/CSO-15270407.pdf',
#  'gs://tfm_javi/CSO-15275295.pdf',
#  'gs://tfm_javi/CSO-15275310.pdf',
#  'gs://tfm_javi/CSO-15275319.pdf',
#  'gs://tfm_javi/CSO-15275324.pdf',
#  'gs://tfm_javi/CSO-15275325.pdf',
#  'gs://tfm_javi/CSO-15275334.pdf',
#  'gs://tfm_javi/CSO-15275348.pdf',
#  'gs://tfm_javi/CSO-15275353.pdf',
#  'gs://tfm_javi/CSO-15275356.pdf',
#  'gs://tfm_javi/CSO-15275367.pdf',
#  'gs://tfm_javi/CSO-15275375.pdf',
#  'gs://tfm_javi/CSO-15281998.pdf',
#  'gs://tfm_javi/CSO-15282001.pdf',
#  'gs://tfm_javi/CSO-15282015.pdf',
#  'gs://tfm_javi/CSO-15282024.pdf',
#  'gs://tfm_javi/CSO-15282026.pdf',
#  'gs://tfm_javi/CSO-15282039.pdf',
#  'gs://tfm_javi/CSO-15282043.pdf',
#  'gs://tfm_javi/CSO-15282067.pdf',
#  'gs://tfm_javi/CSO-15287991.pdf',
#  'gs://tfm_javi/CSO-15287996.pdf',
#  'gs://tfm_javi/CSO-15288003.pdf',
#  'gs://tfm_javi/CSO-15288019.pdf',
#  'gs://tfm_javi/CSO-15288020.pdf',
#  'gs://tfm_javi/CSO-15288023.pdf',
#  'gs://tfm_javi/CSO-15288024.pdf',
#  'gs://tfm_javi/CSO-15288029.pdf',
#  'gs://tfm_javi/CSO-15288043.pdf',
#  'gs://tfm_javi/CSO-15288046.pdf',
#  'gs://tfm_javi/CSO-15288047.pdf',
#  'gs://tfm_javi/CSO-15288053.pdf',
#  'gs://tfm_javi/CSO-15288059.pdf',
#  'gs://tfm_javi/CSO-15294405.pdf',
#  'gs://tfm_javi/CSO-15294417.pdf',
#  'gs://tfm_javi/CSO-15294423.pdf',
#  'gs://tfm_javi/CSO-15294425.pdf',
#  'gs://tfm_javi/CSO-15294426.pdf',
#  'gs://tfm_javi/CSO-15294443.pdf',
#  'gs://tfm_javi/CSO-15294445.pdf',
#  'gs://tfm_javi/CSO-15294448.pdf',
#  'gs://tfm_javi/CSO-15294470.pdf',
#  'gs://tfm_javi/CSO-15294479.pdf',
#  'gs://tfm_javi/CSO-15294500.pdf',
#  'gs://tfm_javi/CSO-15294501.pdf',
#  'gs://tfm_javi/CSO-15294504.pdf',
#  'gs://tfm_javi/CSO-15294508.pdf',
#  'gs://tfm_javi/CSO-15294512.pdf',
#  'gs://tfm_javi/CSO-15299203.pdf',
#  'gs://tfm_javi/CSO-15299208.pdf',
#  'gs://tfm_javi/CSO-15299210.pdf',
#  'gs://tfm_javi/CSO-15299215.pdf',
#  'gs://tfm_javi/CSO-15299216.pdf',
#  'gs://tfm_javi/CSO-15299225.pdf',
#  'gs://tfm_javi/CSO-15299227.pdf',
#  'gs://tfm_javi/CSO-15299243.pdf',
#  'gs://tfm_javi/CSO-15299246.pdf',
#  'gs://tfm_javi/CSO-15299254.pdf',
#  'gs://tfm_javi/CSO-15299256.pdf',
#  'gs://tfm_javi/CSO-15299263.pdf',
#  'gs://tfm_javi/CSO-15299265.pdf',
#  'gs://tfm_javi/CSO-15299275.pdf',
#  'gs://tfm_javi/CSO-15299278.pdf',
#  'gs://tfm_javi/CSO-15299282.pdf',
#  'gs://tfm_javi/CSO-15299283.pdf',
#  'gs://tfm_javi/CSO-15299286.pdf',
#  'gs://tfm_javi/CSO-15299289.pdf',
#  'gs://tfm_javi/CSO-15299292.pdf',
#  'gs://tfm_javi/CSO-15299297.pdf',
#  'gs://tfm_javi/CSO-15299299.pdf',
#  'gs://tfm_javi/CSO-15299301.pdf',
#  'gs://tfm_javi/CSO-15299303.pdf',
#  'gs://tfm_javi/CSO-15299310.pdf',
#  'gs://tfm_javi/CSO-15299314.pdf',
#  'gs://tfm_javi/CSO-15299323.pdf',
#  'gs://tfm_javi/CSO-15299332.pdf',
#  'gs://tfm_javi/CSO-15299335.pdf',
#  'gs://tfm_javi/CSO-15299353.pdf',
#  'gs://tfm_javi/CSO-15299360.pdf',
#  'gs://tfm_javi/CSO-15299362.pdf',
#  'gs://tfm_javi/CSO-15299364.pdf',
#  'gs://tfm_javi/CSO-15299378.pdf',
#  'gs://tfm_javi/CSO-15299384.pdf',
#  'gs://tfm_javi/CSO-15299385.pdf',
#  'gs://tfm_javi/CSO-15299388.pdf',
#  'gs://tfm_javi/CSO-15305977.pdf',
#  'gs://tfm_javi/CSO-15305978.pdf',
#  'gs://tfm_javi/CSO-15305988.pdf',
#  'gs://tfm_javi/CSO-15305989.pdf',
#  'gs://tfm_javi/CSO-15305998.pdf',
#  'gs://tfm_javi/CSO-15306004.pdf',
#  'gs://tfm_javi/CSO-15306005.pdf',
#  'gs://tfm_javi/CSO-15306008.pdf',
#  'gs://tfm_javi/CSO-15306011.pdf',
#  'gs://tfm_javi/CSO-15306013.pdf',
#  'gs://tfm_javi/CSO-15306016.pdf',
#  'gs://tfm_javi/CSO-15306025.pdf',
#  'gs://tfm_javi/CSO-15306027.pdf',
#  'gs://tfm_javi/CSO-15306032.pdf',
#  'gs://tfm_javi/CSO-15306041.pdf',
#  'gs://tfm_javi/CSO-15306042.pdf',
#  'gs://tfm_javi/CSO-15306046.pdf',
#  'gs://tfm_javi/CSO-15306054.pdf',
#  'gs://tfm_javi/CSO-15306055.pdf',
#  'gs://tfm_javi/CSO-15306056.pdf',
#  'gs://tfm_javi/CSO-15306060.pdf',
#  'gs://tfm_javi/CSO-15306062.pdf',
#  'gs://tfm_javi/CSO-15306069.pdf',
#  'gs://tfm_javi/CSO-15306075.pdf',
#  'gs://tfm_javi/CSO-15306078.pdf',
#  'gs://tfm_javi/CSO-15306083.pdf',
#  'gs://tfm_javi/CSO-15306084.pdf',
#  'gs://tfm_javi/CSO-15306087.pdf',
#  'gs://tfm_javi/CSO-15306088.pdf',
#  'gs://tfm_javi/CSO-15306108.pdf',
#  'gs://tfm_javi/CSO-15306122.pdf',
#  'gs://tfm_javi/CSO-15306123.pdf',
#  'gs://tfm_javi/CSO-15312051.pdf',
#  'gs://tfm_javi/CSO-15312057.pdf',
#  'gs://tfm_javi/CSO-15312067.pdf',
#  'gs://tfm_javi/CSO-15312070.pdf',
#  'gs://tfm_javi/CSO-15312079.pdf',
#  'gs://tfm_javi/CSO-15312083.pdf',
#  'gs://tfm_javi/CSO-15312088.pdf',
#  'gs://tfm_javi/CSO-15312095.pdf',
#  'gs://tfm_javi/CSO-15312097.pdf',
#  'gs://tfm_javi/CSO-15312104.pdf',
#  'gs://tfm_javi/CSO-15312107.pdf',
#  'gs://tfm_javi/CSO-15312117.pdf',
#  'gs://tfm_javi/CSO-15312150.pdf',
#  'gs://tfm_javi/CSO-15312157.pdf',
#  'gs://tfm_javi/CSO-15312165.pdf',
#  'gs://tfm_javi/CSO-16003366.pdf',
#  'gs://tfm_javi/CSO-16003372.pdf',
#  'gs://tfm_javi/CSO-16003373.pdf',
#  'gs://tfm_javi/CSO-16003374.pdf',
#  'gs://tfm_javi/CSO-16003387.pdf',
#  'gs://tfm_javi/CSO-16003393.pdf',
#  'gs://tfm_javi/CSO-16003398.pdf',
#  'gs://tfm_javi/CSO-16003402.pdf',
#  'gs://tfm_javi/CSO-16003406.pdf',
#  'gs://tfm_javi/CSO-16003409.pdf',
#  'gs://tfm_javi/CSO-16003412.pdf',
#  'gs://tfm_javi/CSO-16003414.pdf',
#  'gs://tfm_javi/CSO-16003419.pdf',
#  'gs://tfm_javi/CSO-16003424.pdf',
#  'gs://tfm_javi/CSO-16003425.pdf',
#  'gs://tfm_javi/CSO-16003428.pdf',
#  'gs://tfm_javi/CSO-16003429.pdf',
#  'gs://tfm_javi/CSO-16003433.pdf',
#  'gs://tfm_javi/CSO-16003439.pdf',
#  'gs://tfm_javi/CSO-16003449.pdf',
#  'gs://tfm_javi/CSO-16003451.pdf',
#  'gs://tfm_javi/CSO-16003454.pdf',
#  'gs://tfm_javi/CSO-16003456.pdf',
#  'gs://tfm_javi/CSO-16007443.pdf',
#  'gs://tfm_javi/CSO-16007446.pdf',
#  'gs://tfm_javi/CSO-16007447.pdf',
#  'gs://tfm_javi/CSO-16007451.pdf',
#  'gs://tfm_javi/CSO-16007456.pdf',
#  'gs://tfm_javi/CSO-16007470.pdf',
#  'gs://tfm_javi/CSO-16007489.pdf',
#  'gs://tfm_javi/CSO-16007490.pdf',
#  'gs://tfm_javi/CSO-16016928.pdf',
#  'gs://tfm_javi/CSO-16016930.pdf',
#  'gs://tfm_javi/CSO-16016938.pdf',
#  'gs://tfm_javi/CSO-16016941.pdf',
#  'gs://tfm_javi/CSO-16016946.pdf',
#  'gs://tfm_javi/CSO-16016957.pdf',
#  'gs://tfm_javi/CSO-16016960.pdf',
#  'gs://tfm_javi/CSO-16016970.pdf',
#  'gs://tfm_javi/CSO-16016982.pdf',
#  'gs://tfm_javi/CSO-16016983.pdf',
#  'gs://tfm_javi/CSO-16016984.pdf',
#  'gs://tfm_javi/CSO-16019029.pdf',
#  'gs://tfm_javi/CSO-16019030.pdf',
#  'gs://tfm_javi/CSO-16019039.pdf',
#  'gs://tfm_javi/CSO-16019052.pdf',
#  'gs://tfm_javi/CSO-16019055.pdf',
#  'gs://tfm_javi/CSO-16019065.pdf',
#  'gs://tfm_javi/CSO-16019067.pdf',
#  'gs://tfm_javi/CSO-16019072.pdf',
#  'gs://tfm_javi/CSO-16019076.pdf',
#  'gs://tfm_javi/CSO-16019079.pdf',
#  'gs://tfm_javi/CSO-16019092.pdf',
#  'gs://tfm_javi/CSO-16019093.pdf',
#  'gs://tfm_javi/CSO-16019095.pdf',
#  'gs://tfm_javi/CSO-16019098.pdf',
#  'gs://tfm_javi/CSO-16019102.pdf',
#  'gs://tfm_javi/CSO-16019103.pdf',
#  'gs://tfm_javi/CSO-16019104.pdf',
#  'gs://tfm_javi/CSO-16019118.pdf',
#  'gs://tfm_javi/CSO-16025276.pdf',
#  'gs://tfm_javi/CSO-16025293.pdf',
#  'gs://tfm_javi/CSO-16025300.pdf',
#  'gs://tfm_javi/CSO-16025306.pdf',
#  'gs://tfm_javi/CSO-16025308.pdf',
#  'gs://tfm_javi/CSO-16025316.pdf',
#  'gs://tfm_javi/CSO-16025334.pdf',
#  'gs://tfm_javi/CSO-16025350.pdf',
#  'gs://tfm_javi/CSO-16025351.pdf',
#  'gs://tfm_javi/CSO-16025352.pdf',
#  'gs://tfm_javi/CSO-16025375.pdf',
#  'gs://tfm_javi/CSO-16025377.pdf',
#  'gs://tfm_javi/CSO-16025386.pdf',
#  'gs://tfm_javi/CSO-16025389.pdf',
#  'gs://tfm_javi/CSO-16033024.pdf',
#  'gs://tfm_javi/CSO-16033036.pdf',
#  'gs://tfm_javi/CSO-16033040.pdf',
#  'gs://tfm_javi/CSO-16033047.pdf',
#  'gs://tfm_javi/CSO-16033048.pdf',
#  'gs://tfm_javi/CSO-16033050.pdf',
#  'gs://tfm_javi/CSO-16033055.pdf',
#  'gs://tfm_javi/CSO-16033061.pdf',
#  'gs://tfm_javi/CSO-16033072.pdf',
#  'gs://tfm_javi/CSO-16033076.pdf',
#  'gs://tfm_javi/CSO-16033078.pdf',
#  'gs://tfm_javi/CSO-16033086.pdf',
#  'gs://tfm_javi/CSO-16033091.pdf',
#  'gs://tfm_javi/CSO-16033094.pdf',
#  'gs://tfm_javi/CSO-16033097.pdf',
#  'gs://tfm_javi/CSO-16033102.pdf',
#  'gs://tfm_javi/CSO-16033104.pdf',
#  'gs://tfm_javi/CSO-16033111.pdf',
#  'gs://tfm_javi/CSO-16033112.pdf',
#  'gs://tfm_javi/CSO-16033113.pdf',
#  'gs://tfm_javi/CSO-16033118.pdf',
#  'gs://tfm_javi/CSO-16033121.pdf',
#  'gs://tfm_javi/CSO-16033123.pdf',
#  'gs://tfm_javi/CSO-16040317.pdf',
#  'gs://tfm_javi/CSO-16040321.pdf',
#  'gs://tfm_javi/CSO-16040329.pdf',
#  'gs://tfm_javi/CSO-16040330.pdf',
#  'gs://tfm_javi/CSO-16040331.pdf',
#  'gs://tfm_javi/CSO-16040338.pdf',
#  'gs://tfm_javi/CSO-16040347.pdf',
#  'gs://tfm_javi/CSO-16040353.pdf',
#  'gs://tfm_javi/CSO-16040359.pdf',
#  'gs://tfm_javi/CSO-16040369.pdf',
#  'gs://tfm_javi/CSO-16040370.pdf',
#  'gs://tfm_javi/CSO-16040373.pdf',
#  'gs://tfm_javi/CSO-16040392.pdf',
#  'gs://tfm_javi/CSO-16040394.pdf',
#  'gs://tfm_javi/CSO-16040395.pdf',
#  'gs://tfm_javi/CSO-16040400.pdf',
#  'gs://tfm_javi/CSO-16040406.pdf',
#  'gs://tfm_javi/CSO-16040412.pdf',
#  'gs://tfm_javi/CSO-16040423.pdf',
#  'gs://tfm_javi/CSO-16040426.pdf',
#  'gs://tfm_javi/CSO-16047849.pdf',
#  'gs://tfm_javi/CSO-16047856.pdf',
#  'gs://tfm_javi/CSO-16047865.pdf',
#  'gs://tfm_javi/CSO-16047876.pdf',
#  'gs://tfm_javi/CSO-16047879.pdf',
#  'gs://tfm_javi/CSO-16047896.pdf',
#  'gs://tfm_javi/CSO-16047899.pdf',
#  'gs://tfm_javi/CSO-16047904.pdf',
#  'gs://tfm_javi/CSO-16047905.pdf',
#  'gs://tfm_javi/CSO-16047906.pdf',
#  'gs://tfm_javi/CSO-16047910.pdf',
#  'gs://tfm_javi/CSO-16047921.pdf',
#  'gs://tfm_javi/CSO-16047928.pdf',
#  'gs://tfm_javi/CSO-16047930.pdf',
#  'gs://tfm_javi/CSO-16047947.pdf',
#  'gs://tfm_javi/CSO-16047948.pdf',
#  'gs://tfm_javi/CSO-16047949.pdf',
#  'gs://tfm_javi/CSO-16047950.pdf',
#  'gs://tfm_javi/CSO-16047953.pdf',
#  'gs://tfm_javi/CSO-16047954.pdf',
#  'gs://tfm_javi/CSO-16047966.pdf',
#  'gs://tfm_javi/CSO-16054791.pdf',
#  'gs://tfm_javi/CSO-16054794.pdf',
#  'gs://tfm_javi/CSO-16054796.pdf',
#  'gs://tfm_javi/CSO-16054797.pdf',
#  'gs://tfm_javi/CSO-16054799.pdf',
#  'gs://tfm_javi/CSO-16054807.pdf',
#  'gs://tfm_javi/CSO-16054813.pdf',
#  'gs://tfm_javi/CSO-16054815.pdf',
#  'gs://tfm_javi/CSO-16054828.pdf',
#  'gs://tfm_javi/CSO-16054829.pdf',
#  'gs://tfm_javi/CSO-16054843.pdf',
#  ...]

# %%
# Inicializar una lista para almacenar los resultados
resultados = []

# %%
 for pdf_uri in listado_pdfs_error:
     blob_name = pdf_uri.replace(f"gs://{bucket_name}/", "")
     contenido_pdf = procesar_pdf_desde_gcs_en_memoria(bucket_name, blob_name)
    
      # Verificar si el contenido del PDF no está vacío
     if contenido_pdf.strip():
         try:
              # Invocar la cadena con el contenido del PDF
             res = chain.invoke({"contenido_pdf": contenido_pdf})
              #Agregar el resultado a la lista de resultados
             resultados.append(res)
              #Imprimir el resultado
             print(f"Resultado para {blob_name}:\n{res}\n")
         except Exception as e:
            error_message = f"Ocurrió un error al procesar {blob_name}: {e}"
            print(error_message)
            # Registrar el error en el log
            logging.error(error_message)
     else:
        error_message = f"El contenido de {blob_name} está vacío o no se pudo extraer texto."
        print(error_message)
        # Registrar el error en el log
        logging.error(error_message)
# Out:
# ---------------------------------------------------------------------------
# InvalidResponse                           Traceback (most recent call last)
# File c:\Users\javie\.virtualenvs\TFM-mwc0f3M8\Lib\site-packages\google\cloud\storage\blob.py:4420, in Blob._prep_and_do_download(self, file_obj, client, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    4419 try:
# -> 4420     self._do_download(
#    4421         transport,
#    4422         file_obj,
#    4423         download_url,
#    4424         headers,
#    4425         start,
#    4426         end,
#    4427         raw_download,
#    4428         timeout=timeout,
#    4429         checksum=checksum,
#    4430         retry=retry,
#    4431     )
#    4432 except resumable_media.InvalidResponse as exc:
#
# File c:\Users\javie\.virtualenvs\TFM-mwc0f3M8\Lib\site-packages\google\cloud\storage\blob.py:1041, in Blob._do_download(self, transport, file_obj, download_url, headers, start, end, raw_download, timeout, checksum, retry)
#    1036 with create_trace_span(
#    1037     name=f"Storage.{download_class}/consume",
#    1038     attributes=extra_attributes,
#    1039     api_request=args,
#    1040 ):
# -> 1041     response = download.consume(transport, timeout=timeout)
#    1042     self._extract_headers_from_download(response)
#
# File c:\Users\javie\.virtualenvs\TFM-mwc0f3M8\Lib\site-packages\google\resumable_media\requests\download.py:263, in Download.consume(self, transport, timeout)
#     261     return result
# --> 263 return _request_helpers.wait_and_retry(
#     264     retriable_request, self._get_status_code, self._retry_strategy
#     265 )
#
# File c:\Users\javie\.virtualenvs\TFM-mwc0f3M8\Lib\site-packages\google\resumable_media\requests\_request_helpers.py:155, in wait_and_retry(func, get_status_code, retry_strategy)
#     154 try:
# --> 155     response = func()
#     156 except _CONNECTION_ERROR_CLASSES as e:
#
# File c:\Users\javie\.virtualenvs\TFM-mwc0f3M8\Lib\site-packages\google\resumable_media\requests\download.py:245, in Download.consume.<locals>.retriable_request()
#     241     self._object_generation = _helpers._parse_generation_header(
#     242         result, self._get_headers
#     243     )
# --> 245 self._process_response(result)
#     247 # With decompressive transcoding, GCS serves back the whole file regardless of the range request,
#     248 # thus we reset the stream position to the start of the stream.
#     249 # See: https://cloud.google.com/storage/docs/transcoding#range
#
# File c:\Users\javie\.virtualenvs\TFM-mwc0f3M8\Lib\site-packages\google\resumable_media\_download.py:188, in Download._process_response(self, response)
#     187 self._finished = True
# --> 188 _helpers.require_status_code(
#     189     response, _ACCEPTABLE_STATUS_CODES, self._get_status_code
#     190 )
#
# File c:\Users\javie\.virtualenvs\TFM-mwc0f3M8\Lib\site-packages\google\resumable_media\_helpers.py:108, in require_status_code(response, status_codes, get_status_code, callback)
#     107         callback()
# --> 108     raise common.InvalidResponse(
#     109         response,
#     110         "Request failed with status code",
#     111         status_code,
#     112         "Expected one of",
#     113         *status_codes
#     114     )
#     115 return status_code
#
# InvalidResponse: ('Request failed with status code', 404, 'Expected one of', <HTTPStatus.OK: 200>, <HTTPStatus.PARTIAL_CONTENT: 206>)
#
# During handling of the above exception, another exception occurred:
#
# NotFound                                  Traceback (most recent call last)
# Cell In[59], line 3
#       1 for pdf_uri in listado_pdfs_error:
#       2     blob_name = pdf_uri.replace(f"gs://{bucket_name}/", "")
# ----> 3     contenido_pdf = procesar_pdf_desde_gcs_en_memoria(bucket_name, blob_name)
#       5      # Verificar si el contenido del PDF no está vacío
#       6     if contenido_pdf.strip():
#
# Cell In[41], line 17, in procesar_pdf_desde_gcs_en_memoria(bucket_name, blob_name)
#      16 def procesar_pdf_desde_gcs_en_memoria(bucket_name, blob_name):
# ---> 17     pdf_bytes = leer_blob_en_memoria(bucket_name, blob_name)
#      18     content = extraer_texto_de_pdf_bytes(pdf_bytes)
#      19     return content
#
# Cell In[41], line 5, in leer_blob_en_memoria(bucket_name, blob_name)
#       3 bucket = storage_client.bucket(bucket_name)
#       4 blob = bucket.blob(blob_name)
# ----> 5 pdf_content = blob.download_as_bytes()
#       6 return pdf_content
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File c:\Users\javie\.virtualenvs\TFM-mwc0f3M8\Lib\site-packages\google\cloud\storage\blob.py:1469, in Blob.download_as_bytes(self, client, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    1379 """Download the contents of this blob as a bytes object.
#    1380
#    1381 If :attr:`user_project` is set on the bucket, bills the API request
#    (...)
#    1464 :raises: :class:`google.cloud.exceptions.NotFound`
#    1465 """
#    1467 string_buffer = BytesIO()
# -> 1469 self._prep_and_do_download(
#    1470     string_buffer,
#    1471     client=client,
#    1472     start=start,
#    1473     end=end,
#    1474     raw_download=raw_download,
#    1475     if_etag_match=if_etag_match,
#    1476     if_etag_not_match=if_etag_not_match,
#    1477     if_generation_match=if_generation_match,
#    1478     if_generation_not_match=if_generation_not_match,
#    1479     if_metageneration_match=if_metageneration_match,
#    1480     if_metageneration_not_match=if_metageneration_not_match,
#    1481     timeout=timeout,
#    1482     checksum=checksum,
#    1483     retry=retry,
#    1484 )
#    1485 return string_buffer.getvalue()
#
# File c:\Users\javie\.virtualenvs\TFM-mwc0f3M8\Lib\site-packages\google\cloud\storage\blob.py:4433, in Blob._prep_and_do_download(self, file_obj, client, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    4420     self._do_download(
#    4421         transport,
#    4422         file_obj,
#    (...)
#    4430         retry=retry,
#    4431     )
#    4432 except resumable_media.InvalidResponse as exc:
# -> 4433     _raise_from_invalid_response(exc)
#
# File c:\Users\javie\.virtualenvs\TFM-mwc0f3M8\Lib\site-packages\google\cloud\storage\blob.py:4905, in _raise_from_invalid_response(error)
#    4901     error_message = str(error)
#    4903 message = f"{response.request.method} {response.request.url}: {error_message}"
# -> 4905 raise exceptions.from_http_status(response.status_code, message, response=response)
#
# NotFound: 404 GET https://storage.googleapis.com/download/storage/v1/b/tfm_javi/o/g?alt=media: No such object: tfm_javi/g: ('Request failed with status code', 404, 'Expected one of', <HTTPStatus.OK: 200>, <HTTPStatus.PARTIAL_CONTENT: 206>)

# %% [markdown]
# ## Errores de analisis
# realizamos en la terminal cat error_log.txt que nos da el resultado de:
#
# error al procesar resoluciones/NCO-SD2022-0073142.pdf
#
# error al procesar resoluciones/NCO-SD2022-0113402.pdf
#
# error al procesar resoluciones/SD2022-0017210.pdf
#
# vamos  a realizar un intento individual con esos documentos

# %%
listado_pdfs_error = f"gs://{bucket_name}/CSO-SD2017-0001227.pdf"

# %%
listado_pdfs_error
# Out:
# 'gs://tfm_javi/CSO-SD2017-0001227.pdf'

# %%
listado_pdfs_error
# Out:
# ('gs://tfm_javi/resoluciones/NCO-SD2022-0073142.pdf',
#  'gs://tfm_javi/resoluciones/NCO-SD2022-0113402.pdf',
#  'gs://tfm_javi/resoluciones/SD2022-0017210.pdf')

# %%
 for pdf_uri in listado_pdfs_error:
     blob_name = pdf_uri.replace(f"gs://{bucket_name}/", "")
     contenido_pdf = procesar_pdf_desde_gcs_en_memoria(bucket_name, blob_name)
    
      # Verificar si el contenido del PDF no está vacío
     if contenido_pdf.strip():
         try:
              # Invocar la cadena con el contenido del PDF
             res = chain.invoke({"contenido_pdf": contenido_pdf})
              #Agregar el resultado a la lista de resultados
             resultados.append(res)
              #Imprimir el resultado
             print(f"Resultado para {blob_name}:\n{res}\n")
         except Exception as e:
            error_message = f"Ocurrió un error al procesar {blob_name}: {e}"
            print(error_message)
            # Registrar el error en el log
            logging.error(error_message)
     else:
        error_message = f"El contenido de {blob_name} está vacío o no se pudo extraer texto."
        print(error_message)
        # Registrar el error en el log
        logging.error(error_message)
# Out:
# Resultado para resoluciones/NCO-SD2022-0073142.pdf:
# {'contenido_pdf': 'REPÚBLICA DE COLOMBIA\nSUPERINTENDENCIA DE INDUSTRIA Y COMERCIO \nResolución N° 16207\nRef. Expediente N° SD2022/0073142\nRef. Reg. Internacional N° 1673357\nPágina 1 de 48Por la cual se decide una solicitud de registro \nLA DIRECTORA DE SIGNOS DISTINTIVOS (E)\nen ejercicio de sus facultades legales y,\nCONSIDERANDO\nQue por escrito presentado ante la Oficina Internacional el día 30 de marzo de 2022 y \nradicada ante la Superintendencia de Industria y Comercio el día 21 de julio de 2022, YS \nFAMILY MAYORISTA 2021 SLU, solicitó el registro de la marca FAMILY (Mixta) para \ndistinguir productos comprendidos en las clases 8, 20, 21 y 24 de la Clasificación \nInternacional de Niza1. \nQue publicado en la Gaceta de Propiedad Industrial No. 974, PRODUCTOS FAMILIA S.A., \npresentó oposición en contra de las clases 20, 21 y 24 con fundamento en las causales \nde irregistrabilidad establecidas en los literales a) y h) del artículo 136 de la Decisión 486 \nde la Comisión de la Comunidad Andina.\nLo anterior con fundamento, entre otros, en los siguientes argumentos:\n“(…) Es necesario resaltar que estos signos conforman una familia de marcas, en \nla que la expresión predominante es “FAMILIA”, la cual, como se ampliará más \nadelante, tiene una protección reforzada, como lo ha manifestado tanto el Tribunal \nde Justicia de la Comunidad Andina (en adelante “TJCA”) como la SIC.\nAdicionalmente, la marca “FAMILIA” es una marca notoriamente conocida y, por lo \ntanto, cuenta con una protección también reforzada por esa calidad, por el \nprolongado periodo de uso de la marca en el mercado y por la reputación que ha \nadquirido en los consumidores, por lo que al Despacho le corresponde en esta \nocasión, garantizar la protección especial que un signo de esta naturaleza merece, \nde conformidad con las disposiciones andinas.\n1 8: Herramientas e instrumentos de mano que funcionan manualmente; artículos de cuchillería, tenedores y cucharas; cubertería de \nmesa, atizadores, alisadores de plomo (herramientas de mano), afiladores, piedras de afilar, abridores de latas (manuales), sierras de \narco, punzones (de mano), brocas (herramientas de mano), herramientas de corte, limas (manuales), estuches para maquinillas de \nafeitar, cuchillos de mano para verduras, abrelatas no eléctricos, morteros, cortadores de pizzas, alicates, tijeras.\n20: Muebles, espejos, marcos; contenedores no metálicos de almacenamiento o transporte; hueso, cuerno, ballena o nácar, en bruto \no semielaborados; conchas; espuma de mar; ámbar amarillo, unidades de almacenaje (mobiliario), cajas de madera o plásticos, \nperchas para ropa.\n21: Utensilios y recipientes para uso doméstico y culinario; utensilios de cocina y vajilla, excepto tenedores, cuchillos y cucharas; peines \ny esponjas; cepillos; materiales para fabricar cepillos; material de limpieza; vidrio en bruto o semielaborado, excepto vidrio de \nconstrucción; artículos de cristalería, porcelana y loza; teteras, esponjas, manoplas exfoliantes; cajas para la mantequilla, cajas para \njabón, cajas de cristal, distribuidores de jabón; bidones de residuos, bañeras de plástico para niños, esponjas para baño, tablas para \namasar; instrumentos de riego, tiestos; porcelana de mesa, cepillos de lavar; rodillos de pastelería, bote para el pan, boles, cubiletes, \ncopas para fruta, cepillos para quitar el polvo, plumeros; vasos, coladores, platos, botellas, moldes de cocina, moldes para cubitos de \nhielo, tapaderas de cacharros, guantes para uso doméstico, guantes para pulir, baldes, utensilios domésticos no metálicos, cubos para \nconservar el hielo, moldes para pasteles, bandejas para pasteles, medidas para pasteles (moldes); jarras, ollas, reposaplatos, artículos \nde cerámica para uso doméstico; pinzas para la ropa, saca-botas, marmitas, hueveras, sacacorchos, cacerolas, especieros; escobas, \nneveras portátiles, neveras portátiles que no sean eléctricas; utensilios de cocina metálicos, artículos de lo ...
#
# Resultado para resoluciones/NCO-SD2022-0113402.pdf:
# {'contenido_pdf': 'REPÚBLICA DE COLOMBIA\nSUPERINTENDENCIA DE INDUSTRIA Y COMERCIO \nResolución N° 64163\nRef. Expediente N° SD2022/0113402\nPágina 1 de 7Ref. Reg. Internacional N° 1692687\nPor la cual se decide una solicitud de registro \nEL DIRECTOR DE SIGNOS DISTINTIVOS\nen ejercicio de sus facultades legales y,\nCONSIDERANDO\nQue por escrito presentado ante la Oficina Internacional el día 29 de julio de 2022 y \nradicada ante la Superintendencia de Industria y Comercio el día 3 de noviembre de 2022, \nSEA6 ENERGY PRIVATE LIMITED, solicitó el registro de la Marca AGROGAIN (Mixta) \npara distinguir productos comprendidos en la clase 1 de la Clasificación Internacional de \nNiza1. \nQue publicado en la Gaceta de Propiedad Industrial No. 990 del 7 de marzo de 2022, \nAGRO GRAIN S.A. presentó oposición contra la solicitud de registro, con base en lo \ndispuesto en el literal a) del artículo 136 de la Decisión 486 de 2000.\nLo anterior con fundamento, entre otros, en los siguientes argumentos:\n“No. Solicitud: 05125606 \nCertificado 318651 07/07/2026 \nMarca: AGRO GRAIN S.A. (mixta) \nClase: 1 \nPropietario: AGRO GRAIN S.A. DE: CARRERA 46 Nº 83A- 57, BLOQUE 25, \nOFICINA 401 ITAGUI ANTIOQUIA (COLOMBIA) \nProd./Serv.: PRODUCTOS FERTILIZANTES (UREA) (…).\n“La marca AGROGAIN (mixta) Clase 1 solicitada y en trámite de registro por \nExpediente No SD2022/0113402, por la sociedad SEA6 ENERGY PRIVATE \nLIMITED de 1ST FLOOR, CENTER FOR CELLULAR AND MOLECULAR \nPLATFORMS, NCBS-TIFR, GKVK POST, BELLARY ROAD, BANGALORE \nKARNATAKA 560065 (IN), es similarmente confundible tanto fonética, ortográfica \ncomo gráficamente al signo distintivo de mis mandantes denominado: AGRO GRAIN \nS.A. (mixta) Clase 1 (…).\n“existe gran similitud de tipo fonético, ortográfico y gráfico, entre los signos en \nconflicto, porque si se observan las marcas enunciadas en su conjunto, claramente \nse aprecia que contienen una estructura similar, debido a que, en cuanto a las \nexpresiones AGROGAIN - AGRO GRAIN, se puede observar que las mismas, no \nsolo tienen una secuencia vocálica idéntica, sino también una secuencia \nconsonántica muy similar, con la sola variación de una letra “R” adicional en la marca \nregistrada; teniendo las marcas en conflicto un final muy similar: “GAIN” vs “GRAIN” \ny un inicio idéntico: “AGRO” vs “AGRO (…)\n“Además de lo anterior, debe tenerse en cuenta que mientras la marca solicitada \ndenominada AGROGAIN Clase 1 Internacional pretende amparar entre sus \nproductos: “FERTILIZANTES”, la marca registrada de mis representados \ndenominada: AGRO GRAIN S.A. Clase 1 Internacional, protege: “PRODUCTOS \n1 1: Fertilizantes; extractos de plantas, a saber, algas rojas y otras macroalgas utilizadas como reguladores del crecimiento vegetal, \nfertilizantes, bioestimulantes para uso agrícola, doméstico y hortícola; acondicionadores de suelos para uso agrícola, doméstico y \nhortícola; polvos y preparaciones para mejorar la calidad de suelos orgánicos; sustancias para conservar semillas, preparaciones \nbiológicas para uso agrícola, abonos.\nResolución N° 64163\nRef. Expediente N° SD2022/0113402\nPágina 2 de 7FERTILIZANTES”, presentándose los fenómenos de la confusión directa, indirecta, \ne inclusive la confusión por asociación.\n“El hecho de que la marca solicitada a registro tenga similitud con la marca registrada \npor la sociedad AGRO GRAIN S.A. DE: ITAGUI ANTIOQUIA (COLOMBIA), implica \nun medio o sistema encaminado a crear confusión respecto de los productos de la \nSociedad Opositora y de aprovecharse del prestigio y reputación de sus marcas.”\nQue dentro del término concedido para tal efecto, SEA6 ENERGY PRIVATE LIMITED no \ndio respuesta a la oposición presentada.\nQue para decidir acerca de la solicitud de registro marcario de la referencia, esta Oficina \nprocederá a realizar el examen de registrabilidad teniendo en cuenta todos los \nargumentos que hayan sido planteados, así como las pruebas presentadas por las partes. \nLo anterior,  ...
#
# Resultado para resoluciones/SD2022-0017210.pdf:
# {'contenido_pdf': 'REPÚBLICA DE COLOMBIA\nSUPERINTENDENCIA DE INDUSTRIA Y COMERCIO \nResolución N° 3966\nRef. Expediente N° SD2022/0017210\nPágina 1 de 8Ref. Reg. Internacional N° 1646922\nPor la cual se niega un registro \nLA DIRECTORA (E) DE SIGNOS DISTINTIVOS\nen ejercicio de sus facultades legales y,\nCONSIDERANDO\nPRIMERO: Que por escrito presentado ante la Oficina Internacional el día 20 de octubre \nde 2021 y radicada ante la Superintendencia de Industria y Comercio el día 24 de febrero \nde 2022, Amcor Flexibles Sélestat SAS, extendió los efectos territoriales del Registro \nInternacional 1646922, correspondiente a la Marca RESPONSIBLE PACKAGING BY \nAMCOR (Nominativa) para distinguir productos comprendidos en las clases 6, 16 y 17 de \nla Clasificación Internacional de Niza1. \nSEGUNDO: Que publicado en la Gaceta de Propiedad Industrial No. 964, no se \npresentaron oposiciones por parte de terceros.\nTERCERO: Que atendiendo las disposiciones establecidas en la Decisión 486 de la \nComunidad Andina, encuentra la Dirección que de conformidad con el artículo 150 de \naquella, es deber de la oficina realizar el estudio de registrabilidad de un signo teniendo \nen cuenta todas y cada una de las causales de irregistrabilidad determinadas por los \nartículos 135 y 136 de la Decisión. Sobre este particular, ha expuesto el Tribunal de \nJusticia de la Comunidad Andina lo siguiente:\n “…a la Oficina Nacional Competente le corresponde realizar el examen de \nregistrabilidad, el que es obligatorio y debe llevarse a cabo aún en el caso de \nque no hubiesen sido presentadas oposiciones; en consecuencia, la Autoridad \nCompetente en ningún caso queda eximida de realizar el examen de fondo \npara conceder o negar el registro. En el caso de que sean presentadas \noposiciones, la Oficina Nacional Competente se pronunciará acerca de ellas \nasí como acerca de la concesión o de la denegación del registro solicitado.”\nCausales de irregistrabilidad en estudio\nLiteral a) del artículo 136 de la Decisión 486\nNo podrán registrarse como marcas aquellos signos cuyo uso en el comercio afectara \nindebidamente un derecho de tercero, en particular cuando: \n1 6: Hojas, películas y hojas metálicas flexibles total o parcialmente metálicas para la fabricación de casquillos de cartuchos o bolsitas \npara contener alimentos; hojas, películas y hojas metálicas flexibles total o parcialmente metálicas para la fabricación de bolsas; \nláminas, películas y hojas metálicas flexibles total o parcialmente metálicas para la fabricación de tapas; materiales de embalaje \nmetálicos para embalar alimentos, productos para beber, productos farmacéuticos, productos para el cuidado de la salud o productos \nindustriales.\n16: Envoltorios de plástico; materias plásticas para empaquetar; rollos de películas plásticas para embalar; películas de materias \nplásticas para envolver y embalar; películas de materias plásticas utilizadas como embalajes para alimentos, productos para beber, \nproductos farmacéuticos, productos para el cuidado de la salud o productos industriales; bolsitas y bolsas de plástico para embalaje; \nbolsas de plástico para envolver y embalar; hojas de materias plásticas para envolver y embalar; bolsitas de plástico para embalaje; \npelículas plásticas adhesivas para envolver; películas plásticas adhesivas para embalaje; películas adherentes y extensibles de \nmaterias plásticas para embalaje; film adherente; rollos de películas plásticas para embalaje; rollos de películas de materias plásticas \npara el empaquetado de alimentos, productos para beber, productos farmacéuticos, productos para el cuidado de la salud o productos \nindustriales; materiales de embalaje de papel o cartón para el empaquetado de alimentos, productos para beber, productos \nfarmacéuticos, productos para el cuidado de la salud o productos industriales.\n17: Películas de polímeros para la industria manufacturera; materias plásticas extrudidas para utilizar en procesos de fabric ...

# %% [markdown]
# Parece que esta vez si que ha procesado bien los tres archivos que diéron error, vamos a construir un df con los resultados

# %%
df_resultados = pd.DataFrame(resultados)

# %%
df_resultados
# Out:
#                                           contenido_pdf  \
# 0     REPÚBLICA DE COLOMBIA\nSUPERINTENDENCIA  DE IN...
# 1     REPÚBLICA DE COLOMBIA\nSUPERINTENDENCIA DE IND...
# 2     REPÚBLICA DE COLOMBIA\nSUPERINTENDENCIA DE IND...
# 3     REPÚBLICA DE COLOMBIA\nSUPERINTENDENCIA DE IND...
# 4     REPÚBLICA DE COLOMBIA\nSUPERINTENDENCIA DE IND...
# ...                                                 ...
# 2551  REPÚBLICA DE COLOMBIA\nSUPERINTENDENCIA DE IND...
# 2552  REPÚBLICA DE COLOMBIA\nSUPERINTENDENCIA DE IND...
# 2553  REPÚBLICA DE COLOMBIA\nSUPERINTENDENCIA DE IND...
# 2554  REPÚBLICA DE COLOMBIA\nSUPERINTENDENCIA DE IND...
# 2555  REPÚBLICA DE COLOMBIA\nSUPERINTENDENCIA DE IND...
#
#                                                    text
# 0     {'numero_expediente': '14258446', 'resolucion'...
# 1     {'numero_expediente': '15006549', 'resolucion'...
# 2     {'numero_expediente': '15030961', 'resolucion'...
# 3     {'numero_expediente': '15036335', 'resolucion'...
# 4     {'numero_expediente': '15036379', 'resolucion'...
# ...                                                 ...
# 2551  {'numero_expediente': 'SD2019/0040431', 'resol...
# 2552  {'numero_expediente': 'SD2021/0031995', 'resol...
# 2553  {'numero_expediente': 'SD2021/0085336', 'resol...
# 2554  {'numero_expediente': 'SD2017/0025025', 'resol...
# 2555  {'numero_expediente': 'SD2017/0081332', 'resol...
#
# [2556 rows x 2 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
df_ai_annotations_full_1 = pd.DataFrame.from_records(df_resultados['text'])

# %%
df_ai_annotations_full_1
# Out:
#      numero_expediente              resolucion numero_de_resolución  \
# 0             14258446  aprobada_con_oposición                82711
# 1             15006549  aprobada_con_oposición                50676
# 2             15030961  aprobada_con_oposición                 3429
# 3             15036335  aprobada_con_oposición                19923
# 4             15036379  aprobada_con_oposición                10639
# ...                ...                     ...                  ...
# 2551    SD2019/0040431  aprobada_con_oposición               220779
# 2552    SD2021/0031995  aprobada_con_oposición                 2853
# 2553    SD2021/0085336  aprobada_con_oposición                82395
# 2554    SD2017/0025025  aprobada_sin_oposicion                64235
# 2555    SD2017/0081332  aprobada_sin_oposicion                41633
#
#                                            denominacion  \
# 0                                              ChaCheer
# 1                                               Granini
# 2                                                SECTRA
# 3                                     BODEGAS RODA SELA
# 4                                                   bag
# ...                                                 ...
# 2551                                          MI WALLET
# 2552                                     ALPECIN HYBRID
# 2553                                               Fini
# 2554  MR-174 Watching the World \n. Designed by Mits...
# 2555  MAKE IT RIGHT MAKE IT MAGIC MAKE IT WORK (Nomi...
#
#                      vigencia                         titular  \
# 0        20 de marzo de 2023.           QIAQIA FOOD CO., LTD.
# 1        26 de agosto de 2030        ECKES-GRANINI GROUP GMBH
# 2          16 de mayo de 2024                       SECTRA AB
# 3         26 de junio de 2022              BODEGAS RODA, S.A.
# 4       29 de octubre de 2024  J. Luscombe Associates Limited
# ...                       ...                             ...
# 2551  20 de noviembre de 2028                     XIAOMI INC.
# 2552       15 de mayo de 2028    DR. KURT WOLFF GMBH & CO. KG
# 2553               04/03/2031              Sánchez Cano, S.A.
# 2554     12 de agosto de 2019          MITSUI CHEMICALS, INC.
# 2555               28.04.2027                 PUBLICIS GROUPE
#
#                                 clase gaceta        tipo  \
# 0                            [29, 30]    719       Mixta
# 1                                  32    726       Mixta
# 2     [9, 10, 16, 35, 38, 41, 42, 44]    755  Nominativa
# 3                                  33    767       Mixta
# 4                 [9, 14, 18, 25, 35]    736       Mixta
# ...                               ...    ...         ...
# 2551                          [9, 36]    863       Mixta
# 2552                           [3, 5]    929       Mixta
# 2553          [5, 29, 30, 35, 36, 41]    963       Mixta
# 2554                                9   None       Mixta
# 2555                       35, 41, 42   None  Nominativa
#
#                fecha_solicitud         fecha_resolucion  \
# 0     24 de noviembre  de 2014  29 de noviembre de 2016
# 1          14 de enero de 2015     26 de agosto de 2020
# 2        12 de febrero de 2015     3 de febrero de 2017
# 3       5 de diciembre de 2014      24 de abril de 2017
# 4        19 de febrero de 2015       8 de marzo de 2017
# ...                        ...                      ...
# 2551   20 de noviembre de 2018    17 de octubre de 2019
# 2552       17 de marzo de 2021      31 de enero de 2022
# 2553                04/03/2021               23/11/2022
# 2554                      None     9 de octubre de 2017
# 2555                05/12/2016      14 de junio de 2018
#
#                                         nombre_opositor  \
# 0                    INVERSIONES CHEERS DEL CARIBE S.A.
# 1                    TORRECAFE AGUILA ROJA [&] CIA S.A.
# 2     ESPECIALISTAS EN RADIOLOGIA S.A.S, SIXTRA CHIL...
# 3                               BODEGAS DE MOSELA LTDA.
# 4                                        OUR BAG S.A.S.
# ...                                                 ...
# 2551                   UALET S.A. COMISIONISTA DE BOLSA
# 2552                                GLAUKOS CORPORATION
# 2553      Finppi Colombia SA.S.\nAlimentos Finca S.A.S.
# 2554                                               None
# 2555                                               None
#
#                               signo_opositor_opositores  \
# 0                                     CHEERS SINCE 2009
# 1                                 GRANINO\n(Nominativa)
# 2                                      ESPECTRA, SIXTRA
# 3                        BODEGAS DE MOSELA (Nominativa)
# 4                                      OUR BAG y b. bag
# ...                                                 ...
# 2551                                              UALET
# 2552                                 IBRID (Nominativo)
# 2553  Finppi, FINCA MININO, FINCA MIRRINGO, F FINCA,...
# 2554                                               None
# 2555                                               None
#
#                                     argumento_oposición  \
# 0     Basada en el literal a) del artículo 136 de la...
# 1     La marca solicitada GRANINI es confundible con...
# 2     Los opositores argumentan que la marca solicit...
# 3     El opositor argumenta que el signo solicitado ...
# 4     Artículo 136 literal a) de la Decisión 486 de ...
# ...                                                 ...
# 2551  La oposición se basa en las causales de irregi...
# 2552  La marca solicitada ALPECIN HYBRID es similar ...
# 2553  Los opositores argumentan que la marca solicit...
# 2554                                               None
# 2555                                               None
#
#                        explicacion_argumentos_oposicion  \
# 0     La oposición argumenta que existe un alto grad...
# 1     El opositor argumenta que existe riesgo de con...
# 2     Los opositores consideran que existe un alto r...
# 3     La oposición se fundamenta en la similitud ent...
# 4     El opositor argumenta que la marca solicitada ...
# ...                                                 ...
# 2551  El opositor argumenta que MI WALLET es similar...
# 2552  El opositor argumenta que la similitud fonétic...
# 2553  Los argumentos de la oposición se basan en la ...
# 2554                                               None
# 2555                                               None
#
#                                    resolucion_organismo
# 0     Declara infundada la oposición interpuesta por...
# 1     Se declara infundada la oposición interpuesta ...
# 2     La Superintendencia de Industria y Comercio de...
# 3     La Superintendencia de Industria y Comercio re...
# 4     Se declara infundada la oposición y se concede...
# ...                                                 ...
# 2551  Se declara INFUNDADA la oposición interpuesta ...
# 2552  Se declara infundada la oposición interpuesta ...
# 2553  Se deniega la extensión de la notoriedad de la...
# 2554  Conceder el registro de la Marca MR-174 Watchi...
# 2555  Conceder el registro de la Marca MAKE IT RIGHT...
#
# [2556 rows x 16 columns]

# %%
df_ai_annotations_full_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2556 entries, 0 to 2555
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   numero_expediente                 2556 non-null   object
#  1   resolucion                        2556 non-null   object
#  2   numero_de_resolución              2556 non-null   object
#  3   denominacion                      2404 non-null   object
#  4   vigencia                          2535 non-null   object
#  5   titular                           2556 non-null   object
#  6   clase                             2555 non-null   object
#  7   gaceta                            588 non-null    object
#  8   tipo                              2556 non-null   object
#  9   fecha_solicitud                   1399 non-null   object
#  10  fecha_resolucion                  2550 non-null   object
#  11  nombre_opositor                   584 non-null    object
#  12  signo_opositor_opositores         579 non-null    object
#  13  argumento_oposición               583 non-null    object
#  14  explicacion_argumentos_oposicion  583 non-null    object
#  15  resolucion_organismo              2539 non-null   object
# dtypes: object(16)
# memory usage: 319.6+ KB

# %%
df_ai_annotations["argumento_oposición"]
# Out:
# 0                                                    N/A
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
#                              ...
# 427    La marca solicitada FleXeDrive (Nominativa) pa...
# 428                                                 None
# 429    El opositor argumenta que el signo solicitado ...
# 430    Artículo 136 literal a) de la Decisión 486 de ...
# 431    Artículo 136 literal a) de la Decisión 486 de ...
# Name: argumento_oposición, Length: 432, dtype: object

# %%
df_ai_annotations_full_1.to_csv("datasetia_full_1.csv")

# %%
df = pd.read_csv("datasetia.csv")

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#     numero_expediente              resolucion  numero_de_resolución  \
# 0      SD2022/0076224  aprobada_sin_oposicion                  3730
# 1      SD2022/0076226  aprobada_sin_oposicion                  3738
# 2      SD2022/0076227  aprobada_sin_oposicion                  3740
# 3      SD2022/0078960  aprobada_sin_oposicion                  3092
# 4      SD2022/0081645  aprobada_sin_oposicion                  3094
# ..                ...                     ...                   ...
# 427    SD2022/0017139    negada_sin_oposicion                  6466
# 428    SD2022/0017171  aprobada_sin_oposicion                  3282
# 429    SD2022/0073142    negada_con_oposicion                 16207
# 430    SD2022/0113402    negada_con_oposicion                 64163
# 431    SD2022/0017210    negada_sin_oposicion                  3966
#
#                        denominacion             vigencia  \
# 0           NESCAFÉ Dolce Gusto neo  15 de julio de 2031
# 1                   DOLCE GUSTO NEO  4 de enero de 2032.
# 2           NESCAFÉ Dolce Gusto neo   4 de enero de 2032
# 3                        MotionSync           02.04.2032
# 4                  Tranter FullServ           04.05.2032
# ..                              ...                  ...
# 427                      FleXeDrive                  NaN
# 428                      AgroVision           15.10.2031
# 429                          FAMILY                  NaN
# 430                        AGROGAIN            No aplica
# 431  RESPONSIBLE PACKAGING BY AMCOR                  NaN
#
#                               titular            clase  gaceta        tipo  \
# 0    Société des Produits Nestlé S.A.               11   981.0       Mixta
# 1    Société des Produits Nestlé S.A.         [29, 30]   981.0  Nominativa
# 2    Société des Produits Nestlé S.A.         [29, 30]   981.0       Mixta
# 3              Honor Device Co., Ltd.                9   976.0  Nominativa
# 4            Tranter International AB         [37, 42]   976.0  Nominativa
# ..                                ...              ...     ...         ...
# 427        SEW-EURODRIVE GmbH & Co KG                7   981.0  Nominativa
# 428                   Agrovision B.V.  [9, 35, 41, 42]   982.0       Mixta
# 429      YS FAMILY MAYORISTA 2021 SLU  [8, 20, 21, 24]   974.0       Mixta
# 430       SEA6 ENERGY PRIVATE LIMITED                1   990.0       Mixta
# 431      Amcor Flexibles Sélestat SAS      [6, 16, 17]   964.0  Nominativa
#
#              fecha_solicitud       fecha_resolucion          nombre_opositor  \
# 0        28 de julio de 2022   6 de febrero de 2023                      NaN
# 1        28 de julio de 2022   6 de febrero de 2023                      NaN
# 2        28 de julio de 2022   6 de febrero de 2023                      NaN
# 3        4 de agosto de 2022   1 de febrero de 2023                      NaN
# 4                 11/08/2022             01/02/2023                      NaN
# ..                       ...                    ...                      ...
# 427  14 de diciembre de 2021  20 de febrero de 2023  HELMERICH & PAYNE, INC.
# 428    24 de febrero de 2022   2 de febrero de 2023                      NaN
# 429      30 de marzo de 2022    30 de marzo de 2023   PRODUCTOS FAMILIA S.A.
# 430      29 de julio de 2022  20 de octubre de 2023          AGRO GRAIN S.A.
# 431    20 de octubre de 2021   8 de febrero de 2023            AMCOR PTY LTD
#
#                              signo_opositor_opositores  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 427                                          FLEXDRIVE
# 428                                                NaN
# 429  FAMILIA, familia, familia miggo, mi familia, G...
# 430                            AGRO GRAIN S.A. (mixta)
# 431                                              AMCOR
#
#                                    argumento_oposición  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 427  La marca solicitada FleXeDrive (Nominativa) pa...
# 428                                                NaN
# 429  El opositor argumenta que el signo solicitado ...
# 430  Artículo 136 literal a) de la Decisión 486 de ...
# 431  Artículo 136 literal a) de la Decisión 486 de ...
#
#                       explicacion_argumentos_oposicion  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 427  El argumento principal se basa en la similitud...
# 428                                                NaN
# 429  La oposición se fundamenta en que el signo sol...
# 430  La oposición se basa en la similitud entre las...
# 431  El signo solicitado (RESPONSIBLE PACKAGING BY ...
#
#                                   resolucion_organismo
# 0    Conceder el registro de la Marca NESCAFÉ Dolce...
# 1    Conceder el registro de la Marca DOLCE GUSTO N...
# 2    Conceder el registro de la Marca NESCAFÉ Dolce...
# 3    Conceder el registro de la Marca MotionSync (N...
# 4    Conceder el registro de la Marca Tranter FullS...
# ..                                                 ...
# 427  Niega el registro de la marca FleXeDrive (Nomi...
# 428  Conceder el registro de la Marca AgroVision (M...
# 429  Se deniega la solicitud de registro de la marc...
# 430  Se declara fundada la oposición interpuesta po...
# 431  Se niega el registro de la marca RESPONSIBLE P...
#
# [432 rows x 16 columns]

# %% [markdown]
# ***JDS:*** *veo haciendo una exploración que XING FA es una marca que al parecer ya esta registrada, y que la SIC ha entrado de oficio en un caso (expediente SD2022/0011834) porque entra en conflicto con esa marca, hago una exploración muy basica a ver si es uno de los casos que ya hemos procesado y aparentemete no, es posible que si que este pero habria que normalizarlo a minusculas etc, pero tambien es muy posible que no este al ser solo 419 elementos del total, habria que hacer un merge con la bbdd del sql que nos dieron de sysmarck*

# %%
df[df["denominacion"].str.contains("XING FA", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [numero_expediente, resolucion, numero_de_resolución, denominacion, vigencia, titular, clase, gaceta, tipo, fecha_solicitud, fecha_resolucion, nombre_opositor, signo_opositor_opositores, argumento_oposición, explicacion_argumentos_oposicion, resolucion_organismo]
# Index: []
